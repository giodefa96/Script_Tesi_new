# %% [markdown]
# Dati inerenti al volume d'acqua erogato.
# Quello che vorrei fare è prendere tutti i dati e creare una tabella con due colonne, una timestamp e l'altra con i valori

# %%
import pandas as pd
import river
from pprint import pprint
from river import compose
from river import linear_model
from river import metrics
from river import evaluate
from river import preprocessing
from river import optim
from river import feature_extraction
from river import stats
import itertools
import datetime as dt
from river import ensemble
from river import stream
from river import datasets
from river import facto
from river import compat
from river import tree
from river import neighbors
from river import multioutput
from river import neural_net
from river import dummy
from river import compat
from river import time_series
import numpy as np
# %matplotlib inline

# %%
path = '/home/giodefa/PycharmProjects/Script_Tesi_new/Dati/Urban Water Demand Data.txt'

def load_idraulic_press_data(data_path):

       dati = pd.read_csv(path, sep='\t', index_col=False, header=0, names=('date','00:00-00:59','01:00-01:59','02:00-02:59','03:00-03:59','04:00-04:59','05:00-05:59','06:00-06:59','07:00-07:59','08:00-08:59','09:00-09:59','10:00-10:59','11:00-11:59','12:00-12:59','13:00-13:59','14:00-14:59','15:00-15:59','16:00-16:59','17:00-17:59','18:00-18:59','19:00-19:59','20:00-20:59','21:00-21:59','22:00-22:59','23:00-23:59'))


       date = dati.date
       dati = dati.drop("date", axis= 1)

       dati = dati.stack().reset_index()

       list_date = []
       for i in date:
              for a in range(0,24):
                     list_date.append(i)

       list_hour = []
       i = 0
       for a in range(0,dati.shape[0]):
              list_hour.append(i)
              i +=1
              if(i == 24):
                     i=0


       dati['date'] = list_date

       dati = dati.rename(columns = {'level_0':'Count_days','level_1':'Hours',0:'Water_volume'})
       dati = dati[['Count_days','date','Hours','Water_volume']]


       dati['date'] = pd.to_datetime(dati['date'], format='%d-%m-%Y')


       dati['days'] = dati['date'].dt.day

       dati['month'] =  dati['date'].dt.month

       dati['hour'] =  list_hour

       return dati

# %%
dati = load_idraulic_press_data(path)
dati.to_csv('dativolum.csv')
# Out:
# /tmp/ipykernel_9329/3041402693.py:5: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   dati = pd.read_csv(path, sep='\t', index_col=False, header=0, names=('date','00:00-00:59','01:00-01:59','02:00-02:59','03:00-03:59','04:00-04:59','05:00-05:59','06:00-06:59','07:00-07:59','08:00-08:59','09:00-09:59','10:00-10:59','11:00-11:59','12:00-12:59','13:00-13:59','14:00-14:59','15:00-15:59','16:00-16:59','17:00-17:59','18:00-18:59','19:00-19:59','20:00-20:59','21:00-21:59','22:00-22:59','23:00-23:59'))

# %%
dati.tail()
# Out:
#       Count_days       date        Hours  Water_volume  days  month  hour
# 8491         353 2013-09-30  19:00-19:59       31425.0    30      9    19
# 8492         353 2013-09-30  20:00-20:59       27188.7    30      9    20
# 8493         353 2013-09-30  21:00-21:59       22630.9    30      9    21
# 8494         353 2013-09-30  22:00-22:59       19858.5    30      9    22
# 8495         353 2013-09-30  23:00-23:59       14057.3    30      9    23

# %%
dati.Water_volume.isna().sum()
# Out:
# 0

# %%
dati.shape[0]
# Out:
# 8496

# %%
dati.Water_volume.plot()
# Out:
# <AxesSubplot:>

# %%
path = '/home/giodefa/PycharmProjects/Script_Tesi_new/Script/DatiTesi/dativolum.csv'

# %%
dati.columns
# Out:
# Index(['Count_days', 'date', 'Hours', 'Water_volume', 'days', 'month', 'hour'], dtype='object')

# %%
def initial_iter():

       path = '/home/giodefa/PycharmProjects/Script_Tesi_new/Script/DatiTesi/dativolum.csv'

       X_y = stream.iter_csv(
              filepath_or_buffer=path,
              converters={
                     'Count_days': int,
                     'Water_volume': float,
                     'days': int,
                     'month': int,
                     'hour': int,
                     '': int
                     },
              parse_dates={'date': '%Y-%m-%d'},
              target='Water_volume'
                      )
       return X_y

# %%
X_y = initial_iter()

# %%
x, y = next(X_y)
x, y
# Out:
# ({'': 14,
#   'Count_days': 0,
#   'date': datetime.datetime(2012, 10, 2, 0, 0),
#   'Hours': '14:00-14:59',
#   'days': 2,
#   'month': 10,
#   'hour': 14},
#  28082.1)

# %%
X_y = initial_iter()
model = compose.Select( 'Count_days', 'hour')
model |= preprocessing.StandardScaler()
model |= linear_model.LinearRegression(optimizer=optim.SGD(0.1))

metric = metrics.MAE()

evaluate.progressive_val_score(X_y, model, metric, print_every=1000)
# Out:
# [1,000] MAE: 4,298.506589
# [2,000] MAE: 3,929.833892
# [3,000] MAE: 3,824.85212
# [4,000] MAE: 3,794.785101
# [5,000] MAE: 3,789.000472
# [6,000] MAE: 3,777.117148
# [7,000] MAE: 3,694.531585
# [8,000] MAE: 3,522.518448
# MAE: 3,518.359897

# %%
def get_hour(x):

    x['hour'] = x['date'].hour
    return x

# %%
X_y = initial_iter()
model = compose.Select( 'Count_days', 'hour')

model |= preprocessing.StandardScaler()
model |= linear_model.LinearRegression(optimizer=optim.SGD(0.001))

evaluate.progressive_val_score(
       dataset= X_y,
       model = model,
       metric = metrics.MAE(),
       moment='date',
       delay=dt.timedelta(days=1),
       print_every=1000
)
# Out:
# [1,000] MAE: 7,318.22845
# [2,000] MAE: 6,792.655681
# [3,000] MAE: 6,604.58596
# [4,000] MAE: 6,569.511179
# [5,000] MAE: 6,511.104836
# [6,000] MAE: 6,480.335698
# [7,000] MAE: 6,364.580589
# [8,000] MAE: 6,085.206851
# MAE: 6,073.956837

# %%
X_y = initial_iter()

model = compose.Pipeline(
    ('scale', preprocessing.StandardScaler()),
    ('lin_reg', linear_model.LinearRegression())
)

# %%
X_y = initial_iter()

# %%
for i in range(0,8496):
       x, y = next(X_y)
       print(x)
# Out:
# {'': 0, 'Count_days': 0, 'date': datetime.datetime(2012, 10, 2, 0, 0), 'Hours': '00:00-00:59', 'days': 2, 'month': 10, 'hour': 0}
# {'': 1, 'Count_days': 0, 'date': datetime.datetime(2012, 10, 2, 0, 0), 'Hours': '01:00-01:59', 'days': 2, 'month': 10, 'hour': 1}
# {'': 2, 'Count_days': 0, 'date': datetime.datetime(2012, 10, 2, 0, 0), 'Hours': '02:00-02:59', 'days': 2, 'month': 10, 'hour': 2}
# {'': 3, 'Count_days': 0, 'date': datetime.datetime(2012, 10, 2, 0, 0), 'Hours': '03:00-03:59', 'days': 2, 'month': 10, 'hour': 3}
# {'': 4, 'Count_days': 0, 'date': datetime.datetime(2012, 10, 2, 0, 0), 'Hours': '04:00-04:59', 'days': 2, 'month': 10, 'hour': 4}
# {'': 5, 'Count_days': 0, 'date': datetime.datetime(2012, 10, 2, 0, 0), 'Hours': '05:00-05:59', 'days': 2, 'month': 10, 'hour': 5}
# {'': 6, 'Count_days': 0, 'date': datetime.datetime(2012, 10, 2, 0, 0), 'Hours': '06:00-06:59', 'days': 2, 'month': 10, 'hour': 6}
# {'': 7, 'Count_days': 0, 'date': datetime.datetime(2012, 10, 2, 0, 0), 'Hours': '07:00-07:59', 'days': 2, 'month': 10, 'hour': 7}
# {'': 8, 'Count_days': 0, 'date': datetime.datetime(2012, 10, 2, 0, 0), 'Hours': '08:00-08:59', 'days': 2, 'month': 10, 'hour': 8}
# {'': 9, 'Count_days': 0, 'date': datetime.datetime(2012, 10, 2, 0, 0), 'Hours': '09:00-09:59', 'days': 2, 'month': 10, 'hour': 9}
# {'': 10, 'Count_days': 0, 'date': datetime.datetime(2012, 10, 2, 0, 0), 'Hours': '10:00-10:59', 'days': 2, 'month': 10, 'hour': 10}
# {'': 11, 'Count_days': 0, 'date': datetime.datetime(2012, 10, 2, 0, 0), 'Hours': '11:00-11:59', 'days': 2, 'month': 10, 'hour': 11}
# {'': 12, 'Count_days': 0, 'date': datetime.datetime(2012, 10, 2, 0, 0), 'Hours': '12:00-12:59', 'days': 2, 'month': 10, 'hour': 12}
# {'': 13, 'Count_days': 0, 'date': datetime.datetime(2012, 10, 2, 0, 0), 'Hours': '13:00-13:59', 'days': 2, 'month': 10, 'hour': 13}
# {'': 14, 'Count_days': 0, 'date': datetime.datetime(2012, 10, 2, 0, 0), 'Hours': '14:00-14:59', 'days': 2, 'month': 10, 'hour': 14}
# {'': 15, 'Count_days': 0, 'date': datetime.datetime(2012, 10, 2, 0, 0), 'Hours': '15:00-15:59', 'days': 2, 'month': 10, 'hour': 15}
# {'': 16, 'Count_days': 0, 'date': datetime.datetime(2012, 10, 2, 0, 0), 'Hours': '16:00-16:59', 'days': 2, 'month': 10, 'hour': 16}
# {'': 17, 'Count_days': 0, 'date': datetime.datetime(2012, 10, 2, 0, 0), 'Hours': '17:00-17:59', 'days': 2, 'month': 10, 'hour': 17}
# {'': 18, 'Count_days': 0, 'date': datetime.datetime(2012, 10, 2, 0, 0), 'Hours': '18:00-18:59', 'days': 2, 'month': 10, 'hour': 18}
# {'': 19, 'Count_days': 0, 'date': datetime.datetime(2012, 10, 2, 0, 0), 'Hours': '19:00-19:59', 'days': 2, 'month': 10, 'hour': 19}
# {'': 20, 'Count_days': 0, 'date': datetime.datetime(2012, 10, 2, 0, 0), 'Hours': '20:00-20:59', 'days': 2, 'month': 10, 'hour': 20}
# {'': 21, 'Count_days': 0, 'date': datetime.datetime(2012, 10, 2, 0, 0), 'Hours': '21:00-21:59', 'days': 2, 'month': 10, 'hour': 21}
# {'': 22, 'Count_days': 0, 'date': datetime.datetime(2012, 10, 2, 0, 0), 'Hours': '22:00-22:59', 'days': 2, 'month': 10, 'hour': 22}
# {'': 23, 'Count_days': 0, 'date': datetime.datetime(2012, 10, 2, 0, 0), 'Hours': '23:00-23:59', 'days': 2, 'month': 10, 'hour': 23}
# {'': 24, 'Count_days': 1, 'date': datetime.datetime(2012, 10, 3, 0, 0), 'Hours': '00:00-00:59', 'days': 3, 'month': 10, 'hour': 0}
# {'': 25, 'Count_days': 1, 'date': datetime.datetime(2012, 10, 3, 0, 0), 'Hours': '01:00-01:59', 'days': 3, 'month': 10, 'hour': 1}
# {'': 26, 'Count_days': 1, 'date': datetime.datetime(2012, 10, 3, 0, 0), 'Hours': '02:00-02:59', 'days': 3, 'month': 10, 'hour': 2}
# {'': 27, 'Count_days': 1, 'date': datetime.datetime(2012, 10, 3, 0, 0), 'Hours': '03:00-03:59', 'days': 3, 'month': 10, 'hour': 3}
# {'': 28, 'Count_days': 1, 'date': datetime.datetime(2012, 10, 3, 0, 0), 'Hours': '04:00-04:59', 'days': 3, 'month': 10, 'hour': 4}
# {'': 29, 'Count_days': 1, 'date': datetime.datetime(2012, 10, 3, 0, 0), 'Hours': '05:00-05:59', 'days': 3, 'month': 10, 'hour': 5}
# {'': 30, 'Count_days': 1, 'date': datetime.datetime(2012, 10, 3, 0, 0), 'Hours': '06:00-06:59', 'days': 3, 'month': 10, 'hour': 6}
# {'': 31, 'Count_days': 1, 'date': datetime.datetime(2012, 10, 3, 0, 0), 'Hours': '07:00-07:59', 'days': 3, 'month': 10, 'hour': 7}
# {'': 32, 'Count_days': 1, 'date': datetime.datetime(2012, 10, 3, 0, 0), 'Hours': '08:00-08:59', 'days': 3, 'month': 10, 'hour': 8}
# {'': 33, 'Count_days': 1, 'date': datetime.datetime(2012, 10, 3, 0, 0), 'Hours': '09:00-09:59', 'days': 3, 'month': 10, 'hour': 9}
# {'': 34, 'Count_days': 1, 'date': datetime.datetime(2012, 10, 3, 0, 0), 'Hours': '10:00-10:59', 'days': 3, 'month': 10, 'hour': 10}
# {'': 35, 'Count_days': 1, 'date': datetime.datetime(2012, 10, 3, 0, 0), 'Hours': '11:00-11:59', 'days': 3, 'month': 10, 'hour': 11}
# {'': 36, 'Count_days': 1, 'date': datetime.datetime(2012, 10, 3, 0, 0), 'Hours': '12:00-12:59', 'days': 3, 'month': 10, 'hour': 12}
# {'': 37, 'Count_days': 1, 'date': datetime.datetime(2012, 10, 3, 0, 0), 'Hours': '13:00-13:59', 'days': 3, 'month': 10, 'hour': 13}
# {'': 38, 'Count_days': 1, 'date': datetime.datetime(2012, 10, 3, 0, 0), 'Hours': '14:00-14:59', 'days': 3, 'month': 10, 'hour': 14}
# {'': 39, 'Count_days': 1, 'date': datetime.datetime(2012, 10, 3, 0, 0), 'Hours': '15:00-15:59', 'days': 3, 'month': 10, 'hour': 15}
# {'': 40, 'Count_days': 1, 'date': datetime.datetime(2012, 10, 3, 0, 0), 'Hours': '16:00-16:59', 'days': 3, 'month': 10, 'hour': 16}
# {'': 41, 'Count_days': 1, 'date': datetime.datetime(2012, 10, 3, 0, 0), 'Hours': '17:00-17:59', 'days': 3, 'month': 10, 'hour': 17}
# {'': 42, 'Count_days': 1, 'date': datetime.datetime(2012, 10, 3, 0, 0), 'Hours': '18:00-18:59', 'days': 3, 'month': 10, 'hour': 18}
# {'': 43, 'Count_days': 1, 'date': datetime.datetime(2012, 10, 3, 0, 0), 'Hours': '19:00-19:59', 'days': 3, 'month': 10, 'hour': 19}
# {'': 44, 'Count_days': 1, 'date': datetime.datetime(2012, 10, 3, 0, 0), 'Hours': '20:00-20:59', 'days': 3, 'month': 10, 'hour': 20}
# {'': 45, 'Count_days': 1, 'date': datetime.datetime(2012, 10, 3, 0, 0), 'Hours': '21:00-21:59', 'days': 3, 'month': 10, 'hour': 21}
# {'': 46, 'Count_days': 1, 'date': datetime.datetime(2012, 10, 3, 0, 0), 'Hours': '22:00-22:59', 'days': 3, 'month': 10, 'hour': 22}
# {'': 47, 'Count_days': 1, 'date': datetime.datetime(2012, 10, 3, 0, 0), 'Hours': '23:00-23:59', 'days': 3, 'month': 10, 'hour': 23}
# {'': 48, 'Count_days': 2, 'date': datetime.datetime(2012, 10, 4, 0, 0), 'Hours': '00:00-00:59', 'days': 4, 'month': 10, 'hour': 0}
# {'': 49, 'Count_days': 2, 'date': datetime.datetime(2012, 10, 4, 0, 0), 'Hours': '01:00-01:59', 'days': 4, 'month': 10, 'hour': 1}
# {'': 50, 'Count_days': 2, 'date': datetime.datetime(2012, 10, 4, 0, 0), 'Hours': '02:00-02:59', 'days': 4, 'month': 10, 'hour': 2}
# {'': 51, 'Count_days': 2, 'date': datetime.datetime(2012, 10, 4, 0, 0), 'Hours': '03:00-03:59', 'days': 4, 'month': 10, 'hour': 3}
# {'': 52, 'Count_days': 2, 'date': datetime.datetime(2012, 10, 4, 0, 0), 'Hours': '04:00-04:59', 'days': 4, 'month': 10, 'hour': 4}
# {'': 53, 'Count_days': 2, 'date': datetime.datetime(2012, 10, 4, 0, 0), 'Hours': '05:00-05:59', 'days': 4, 'month': 10, 'hour': 5}
# {'': 54, 'Count_days': 2, 'date': datetime.datetime(2012, 10, 4, 0, 0), 'Hours': '06:00-06:59', 'days': 4, 'month': 10, 'hour': 6}
# {'': 55, 'Count_days': 2, 'date': datetime.datetime(2012, 10, 4, 0, 0), 'Hours': '07:00-07:59', 'days': 4, 'month': 10, 'hour': 7}
# {'': 56, 'Count_days': 2, 'date': datetime.datetime(2012, 10, 4, 0, 0), 'Hours': '08:00-08:59', 'days': 4, 'month': 10, 'hour': 8}
# {'': 57, 'Count_days': 2, 'date': datetime.datetime(2012, 10, 4, 0, 0), 'Hours': '09:00-09:59', 'days': 4, 'month': 10, 'hour': 9}
# {'': 58, 'Count_days': 2, 'date': datetime.datetime(2012, 10, 4, 0, 0), 'Hours': '10:00-10:59', 'days': 4, 'month': 10, 'hour': 10}
# {'': 59, 'Count_days': 2, 'date': datetime.datetime(2012, 10, 4, 0, 0), 'Hours': '11:00-11:59', 'days': 4, 'month': 10, 'hour': 11}
# {'': 60, 'Count_days': 2, 'date': datetime.datetime(2012, 10, 4, 0, 0), 'Hours': '12:00-12:59', 'days': 4, 'month': 10, 'hour': 12}
# {'': 61, 'Count_days': 2, 'date': datetime.datetime(2012, 10, 4, 0, 0), 'Hours': '13:00-13:59', 'days': 4, 'month': 10, 'hour': 13}
# {'': 62, 'Count_days': 2, 'date': datetime.datetime(2012, 10, 4, 0, 0), 'Hours': '14:00-14:59', 'days': 4, 'month': 10, 'hour': 14}
# {'': 63, 'Count_days': 2, 'date': datetime.datetime(2012, 10, 4, 0, 0), 'Hours': '15:00-15:59', 'days': 4, 'month': 10, 'hour': 15}
# {'': 64, 'Count_days': 2, 'date': datetime.datetime(2012, 10, 4, 0, 0), 'Hours': '16:00-16:59', 'days': 4, 'month': 10, 'hour': 16}
# {'': 65, 'Count_days': 2, 'date': datetime.datetime(2012, 10, 4, 0, 0), 'Hours': '17:00-17:59', 'days': 4, 'month': 10, 'hour': 17}
# {'': 66, 'Count_days': 2, 'date': datetime.datetime(2012, 10, 4, 0, 0), 'Hours': '18:00-18:59', 'days': 4, 'month': 10, 'hour': 18}
# {'': 67, 'Count_days': 2, 'date': datetime.datetime(2012, 10, 4, 0, 0), 'Hours': '19:00-19:59', 'days': 4, 'month': 10, 'hour': 19}
# {'': 68, 'Count_days': 2, 'date': datetime.datetime(2012, 10, 4, 0, 0), 'Hours': '20:00-20:59', 'days': 4, 'month': 10, 'hour': 20}
# {'': 69, 'Count_days': 2, 'date': datetime.datetime(2012, 10, 4, 0, 0), 'Hours': '21:00-21:59', 'days': 4, 'month': 10, 'hour': 21}
# {'': 70, 'Count_days': 2, 'date': datetime.datetime(2012, 10, 4, 0, 0), 'Hours': '22:00-22:59', 'days': 4, 'month': 10, 'hour': 22}
# {'': 71, 'Count_days': 2, 'date': datetime.datetime(2012, 10, 4, 0, 0), 'Hours': '23:00-23:59', 'days': 4, 'month': 10, 'hour': 23}
# {'': 72, 'Count_days': 3, 'date': datetime.datetime(2012, 10, 5, 0, 0), 'Hours': '00:00-00:59', 'days': 5, 'month': 10, 'hour': 0}
# {'': 73, 'Count_days': 3, 'date': datetime.datetime(2012, 10, 5, 0, 0), 'Hours': '01:00-01:59', 'days': 5, 'month': 10, 'hour': 1}
# {'': 74, 'Count_days': 3, 'date': datetime.datetime(2012, 10, 5, 0, 0), 'Hours': '02:00-02:59', 'days': 5, 'month': 10, 'hour': 2}
# {'': 75, 'Count_days': 3, 'date': datetime.datetime(2012, 10, 5, 0, 0), 'Hours': '03:00-03:59', 'days': 5, 'month': 10, 'hour': 3}
# {'': 76, 'Count_days': 3, 'date': datetime.datetime(2012, 10, 5, 0, 0), 'Hours': '04:00-04:59', 'days': 5, 'month': 10, 'hour': 4}
# {'': 77, 'Count_days': 3, 'date': datetime.datetime(2012, 10, 5, 0, 0), 'Hours': '05:00-05:59', 'days': 5, 'month': 10, 'hour': 5}
# {'': 78, 'Count_days': 3, 'date': datetime.datetime(2012, 10, 5, 0, 0), 'Hours': '06:00-06:59', 'days': 5, 'month': 10, 'hour': 6}
# {'': 79, 'Count_days': 3, 'date': datetime.datetime(2012, 10, 5, 0, 0), 'Hours': '07:00-07:59', 'days': 5, 'month': 10, 'hour': 7}
# {'': 80, 'Count_days': 3, 'date': datetime.datetime(2012, 10, 5, 0, 0), 'Hours': '08:00-08:59', 'days': 5, 'month': 10, 'hour': 8}
# {'': 81, 'Count_days': 3, 'date': datetime.datetime(2012, 10, 5, 0, 0), 'Hours': '09:00-09:59', 'days': 5, 'month': 10, 'hour': 9}
# {'': 82, 'Count_days': 3, 'date': datetime.datetime(2012, 10, 5, 0, 0), 'Hours': '10:00-10:59', 'days': 5, 'month': 10, 'hour': 10}
# {'': 83, 'Count_days': 3, 'date': datetime.datetime(2012, 10, 5, 0, 0), 'Hours': '11:00-11:59', 'days': 5, 'month': 10, 'hour': 11}
# {'': 84, 'Count_days': 3, 'date': datetime.datetime(2012, 10, 5, 0, 0), 'Hours': '12:00-12:59', 'days': 5, 'month': 10, 'hour': 12}
# {'': 85, 'Count_days': 3, 'date': datetime.datetime(2012, 10, 5, 0, 0), 'Hours': '13:00-13:59', 'days': 5, 'month': 10, 'hour': 13}
# {'': 86, 'Count_days': 3, 'date': datetime.datetime(2012, 10, 5, 0, 0), 'Hours': '14:00-14:59', 'days': 5, 'month': 10, 'hour': 14}
# {'': 87, 'Count_days': 3, 'date': datetime.datetime(2012, 10, 5, 0, 0), 'Hours': '15:00-15:59', 'days': 5, 'month': 10, 'hour': 15}
# {'': 88, 'Count_days': 3, 'date': datetime.datetime(2012, 10, 5, 0, 0), 'Hours': '16:00-16:59', 'days': 5, 'month': 10, 'hour': 16}
# {'': 89, 'Count_days': 3, 'date': datetime.datetime(2012, 10, 5, 0, 0), 'Hours': '17:00-17:59', 'days': 5, 'month': 10, 'hour': 17}
# {'': 90, 'Count_days': 3, 'date': datetime.datetime(2012, 10, 5, 0, 0), 'Hours': '18:00-18:59', 'days': 5, 'month': 10, 'hour': 18}
# {'': 91, 'Count_days': 3, 'date': datetime.datetime(2012, 10, 5, 0, 0), 'Hours': '19:00-19:59', 'days': 5, 'month': 10, 'hour': 19}
# {'': 92, 'Count_days': 3, 'date': datetime.datetime(2012, 10, 5, 0, 0), 'Hours': '20:00-20:59', 'days': 5, 'month': 10, 'hour': 20}
# {'': 93, 'Count_days': 3, 'date': datetime.datetime(2012, 10, 5, 0, 0), 'Hours': '21:00-21:59', 'days': 5, 'month': 10, 'hour': 21}
# {'': 94, 'Count_days': 3, 'date': datetime.datetime(2012, 10, 5, 0, 0), 'Hours': '22:00-22:59', 'days': 5, 'month': 10, 'hour': 22}
# {'': 95, 'Count_days': 3, 'date': datetime.datetime(2012, 10, 5, 0, 0), 'Hours': '23:00-23:59', 'days': 5, 'month': 10, 'hour': 23}
# {'': 96, 'Count_days': 4, 'date': datetime.datetime(2012, 10, 6, 0, 0), 'Hours': '00:00-00:59', 'days': 6, 'month': 10, 'hour': 0}
# {'': 97, 'Count_days': 4, 'date': datetime.datetime(2012, 10, 6, 0, 0), 'Hours': '01:00-01:59', 'days': 6, 'month': 10, 'hour': 1}
# {'': 98, 'Count_days': 4, 'date': datetime.datetime(2012, 10, 6, 0, 0), 'Hours': '02:00-02:59', 'days': 6, 'month': 10, 'hour': 2}
# {'': 99, 'Count_days': 4, 'date': datetime.datetime(2012, 10, 6, 0, 0), 'Hours': '03:00-03:59', 'days': 6, 'month': 10, 'hour': 3}
# {'': 100, 'Count_days': 4, 'date': datetime.datetime(2012, 10, 6, 0, 0), 'Hours': '04:00-04:59', 'days': 6, 'month': 10, 'hour': 4}
# {'': 101, 'Count_days': 4, 'date': datetime.datetime(2012, 10, 6, 0, 0), 'Hours': '05:00-05:59', 'days': 6, 'month': 10, 'hour': 5}
# {'': 102, 'Count_days': 4, 'date': datetime.datetime(2012, 10, 6, 0, 0), 'Hours': '06:00-06:59', 'days': 6, 'month': 10, 'hour': 6}
# {'': 103, 'Count_days': 4, 'date': datetime.datetime(2012, 10, 6, 0, 0), 'Hours': '07:00-07:59', 'days': 6, 'month': 10, 'hour': 7}
# {'': 104, 'Count_days': 4, 'date': datetime.datetime(2012, 10, 6, 0, 0), 'Hours': '08:00-08:59', 'days': 6, 'month': 10, 'hour': 8}
# {'': 105, 'Count_days': 4, 'date': datetime.datetime(2012, 10, 6, 0, 0), 'Hours': '09:00-09:59', 'days': 6, 'month': 10, 'hour': 9}
# {'': 106, 'Count_days': 4, 'date': datetime.datetime(2012, 10, 6, 0, 0), 'Hours': '10:00-10:59', 'days': 6, 'month': 10, 'hour': 10}
# {'': 107, 'Count_days': 4, 'date': datetime.datetime(2012, 10, 6, 0, 0), 'Hours': '11:00-11:59', 'days': 6, 'month': 10, 'hour': 11}
# {'': 108, 'Count_days': 4, 'date': datetime.datetime(2012, 10, 6, 0, 0), 'Hours': '12:00-12:59', 'days': 6, 'month': 10, 'hour': 12}
# {'': 109, 'Count_days': 4, 'date': datetime.datetime(2012, 10, 6, 0, 0), 'Hours': '13:00-13:59', 'days': 6, 'month': 10, 'hour': 13}
# {'': 110, 'Count_days': 4, 'date': datetime.datetime(2012, 10, 6, 0, 0), 'Hours': '14:00-14:59', 'days': 6, 'month': 10, 'hour': 14}
# {'': 111, 'Count_days': 4, 'date': datetime.datetime(2012, 10, 6, 0, 0), 'Hours': '15:00-15:59', 'days': 6, 'month': 10, 'hour': 15}
# {'': 112, 'Count_days': 4, 'date': datetime.datetime(2012, 10, 6, 0, 0), 'Hours': '16:00-16:59', 'days': 6, 'month': 10, 'hour': 16}
# {'': 113, 'Count_days': 4, 'date': datetime.datetime(2012, 10, 6, 0, 0), 'Hours': '17:00-17:59', 'days': 6, 'month': 10, 'hour': 17}
# {'': 114, 'Count_days': 4, 'date': datetime.datetime(2012, 10, 6, 0, 0), 'Hours': '18:00-18:59', 'days': 6, 'month': 10, 'hour': 18}
# {'': 115, 'Count_days': 4, 'date': datetime.datetime(2012, 10, 6, 0, 0), 'Hours': '19:00-19:59', 'days': 6, 'month': 10, 'hour': 19}
# {'': 116, 'Count_days': 4, 'date': datetime.datetime(2012, 10, 6, 0, 0), 'Hours': '20:00-20:59', 'days': 6, 'month': 10, 'hour': 20}
# {'': 117, 'Count_days': 4, 'date': datetime.datetime(2012, 10, 6, 0, 0), 'Hours': '21:00-21:59', 'days': 6, 'month': 10, 'hour': 21}
# {'': 118, 'Count_days': 4, 'date': datetime.datetime(2012, 10, 6, 0, 0), 'Hours': '22:00-22:59', 'days': 6, 'month': 10, 'hour': 22}
# {'': 119, 'Count_days': 4, 'date': datetime.datetime(2012, 10, 6, 0, 0), 'Hours': '23:00-23:59', 'days': 6, 'month': 10, 'hour': 23}
# {'': 120, 'Count_days': 5, 'date': datetime.datetime(2012, 10, 7, 0, 0), 'Hours': '00:00-00:59', 'days': 7, 'month': 10, 'hour': 0}
# {'': 121, 'Count_days': 5, 'date': datetime.datetime(2012, 10, 7, 0, 0), 'Hours': '01:00-01:59', 'days': 7, 'month': 10, 'hour': 1}
# {'': 122, 'Count_days': 5, 'date': datetime.datetime(2012, 10, 7, 0, 0), 'Hours': '02:00-02:59', 'days': 7, 'month': 10, 'hour': 2}
# {'': 123, 'Count_days': 5, 'date': datetime.datetime(2012, 10, 7, 0, 0), 'Hours': '03:00-03:59', 'days': 7, 'month': 10, 'hour': 3}
# {'': 124, 'Count_days': 5, 'date': datetime.datetime(2012, 10, 7, 0, 0), 'Hours': '04:00-04:59', 'days': 7, 'month': 10, 'hour': 4}
# {'': 125, 'Count_days': 5, 'date': datetime.datetime(2012, 10, 7, 0, 0), 'Hours': '05:00-05:59', 'days': 7, 'month': 10, 'hour': 5}
# {'': 126, 'Count_days': 5, 'date': datetime.datetime(2012, 10, 7, 0, 0), 'Hours': '06:00-06:59', 'days': 7, 'month': 10, 'hour': 6}
# {'': 127, 'Count_days': 5, 'date': datetime.datetime(2012, 10, 7, 0, 0), 'Hours': '07:00-07:59', 'days': 7, 'month': 10, 'hour': 7}
# {'': 128, 'Count_days': 5, 'date': datetime.datetime(2012, 10, 7, 0, 0), 'Hours': '08:00-08:59', 'days': 7, 'month': 10, 'hour': 8}
# {'': 129, 'Count_days': 5, 'date': datetime.datetime(2012, 10, 7, 0, 0), 'Hours': '09:00-09:59', 'days': 7, 'month': 10, 'hour': 9}
# {'': 130, 'Count_days': 5, 'date': datetime.datetime(2012, 10, 7, 0, 0), 'Hours': '10:00-10:59', 'days': 7, 'month': 10, 'hour': 10}
# {'': 131, 'Count_days': 5, 'date': datetime.datetime(2012, 10, 7, 0, 0), 'Hours': '11:00-11:59', 'days': 7, 'month': 10, 'hour': 11}
# {'': 132, 'Count_days': 5, 'date': datetime.datetime(2012, 10, 7, 0, 0), 'Hours': '12:00-12:59', 'days': 7, 'month': 10, 'hour': 12}
# {'': 133, 'Count_days': 5, 'date': datetime.datetime(2012, 10, 7, 0, 0), 'Hours': '13:00-13:59', 'days': 7, 'month': 10, 'hour': 13}
# {'': 134, 'Count_days': 5, 'date': datetime.datetime(2012, 10, 7, 0, 0), 'Hours': '14:00-14:59', 'days': 7, 'month': 10, 'hour': 14}
# {'': 135, 'Count_days': 5, 'date': datetime.datetime(2012, 10, 7, 0, 0), 'Hours': '15:00-15:59', 'days': 7, 'month': 10, 'hour': 15}
# {'': 136, 'Count_days': 5, 'date': datetime.datetime(2012, 10, 7, 0, 0), 'Hours': '16:00-16:59', 'days': 7, 'month': 10, 'hour': 16}
# {'': 137, 'Count_days': 5, 'date': datetime.datetime(2012, 10, 7, 0, 0), 'Hours': '17:00-17:59', 'days': 7, 'month': 10, 'hour': 17}
# {'': 138, 'Count_days': 5, 'date': datetime.datetime(2012, 10, 7, 0, 0), 'Hours': '18:00-18:59', 'days': 7, 'month': 10, 'hour': 18}
# {'': 139, 'Count_days': 5, 'date': datetime.datetime(2012, 10, 7, 0, 0), 'Hours': '19:00-19:59', 'days': 7, 'month': 10, 'hour': 19}
# {'': 140, 'Count_days': 5, 'date': datetime.datetime(2012, 10, 7, 0, 0), 'Hours': '20:00-20:59', 'days': 7, 'month': 10, 'hour': 20}
# {'': 141, 'Count_days': 5, 'date': datetime.datetime(2012, 10, 7, 0, 0), 'Hours': '21:00-21:59', 'days': 7, 'month': 10, 'hour': 21}
# {'': 142, 'Count_days': 5, 'date': datetime.datetime(2012, 10, 7, 0, 0), 'Hours': '22:00-22:59', 'days': 7, 'month': 10, 'hour': 22}
# {'': 143, 'Count_days': 5, 'date': datetime.datetime(2012, 10, 7, 0, 0), 'Hours': '23:00-23:59', 'days': 7, 'month': 10, 'hour': 23}
# {'': 144, 'Count_days': 6, 'date': datetime.datetime(2012, 10, 8, 0, 0), 'Hours': '00:00-00:59', 'days': 8, 'month': 10, 'hour': 0}
# {'': 145, 'Count_days': 6, 'date': datetime.datetime(2012, 10, 8, 0, 0), 'Hours': '01:00-01:59', 'days': 8, 'month': 10, 'hour': 1}
# {'': 146, 'Count_days': 6, 'date': datetime.datetime(2012, 10, 8, 0, 0), 'Hours': '02:00-02:59', 'days': 8, 'month': 10, 'hour': 2}
# {'': 147, 'Count_days': 6, 'date': datetime.datetime(2012, 10, 8, 0, 0), 'Hours': '03:00-03:59', 'days': 8, 'month': 10, 'hour': 3}
# {'': 148, 'Count_days': 6, 'date': datetime.datetime(2012, 10, 8, 0, 0), 'Hours': '04:00-04:59', 'days': 8, 'month': 10, 'hour': 4}
# {'': 149, 'Count_days': 6, 'date': datetime.datetime(2012, 10, 8, 0, 0), 'Hours': '05:00-05:59', 'days': 8, 'month': 10, 'hour': 5}
# {'': 150, 'Count_days': 6, 'date': datetime.datetime(2012, 10, 8, 0, 0), 'Hours': '06:00-06:59', 'days': 8, 'month': 10, 'hour': 6}
# {'': 151, 'Count_days': 6, 'date': datetime.datetime(2012, 10, 8, 0, 0), 'Hours': '07:00-07:59', 'days': 8, 'month': 10, 'hour': 7}
# {'': 152, 'Count_days': 6, 'date': datetime.datetime(2012, 10, 8, 0, 0), 'Hours': '08:00-08:59', 'days': 8, 'month': 10, 'hour': 8}
# {'': 153, 'Count_days': 6, 'date': datetime.datetime(2012, 10, 8, 0, 0), 'Hours': '09:00-09:59', 'days': 8, 'month': 10, 'hour': 9}
# {'': 154, 'Count_days': 6, 'date': datetime.datetime(2012, 10, 8, 0, 0), 'Hours': '10:00-10:59', 'days': 8, 'month': 10, 'hour': 10}
# {'': 155, 'Count_days': 6, 'date': datetime.datetime(2012, 10, 8, 0, 0), 'Hours': '11:00-11:59', 'days': 8, 'month': 10, 'hour': 11}
# {'': 156, 'Count_days': 6, 'date': datetime.datetime(2012, 10, 8, 0, 0), 'Hours': '12:00-12:59', 'days': 8, 'month': 10, 'hour': 12}
# {'': 157, 'Count_days': 6, 'date': datetime.datetime(2012, 10, 8, 0, 0), 'Hours': '13:00-13:59', 'days': 8, 'month': 10, 'hour': 13}
# {'': 158, 'Count_days': 6, 'date': datetime.datetime(2012, 10, 8, 0, 0), 'Hours': '14:00-14:59', 'days': 8, 'month': 10, 'hour': 14}
# {'': 159, 'Count_days': 6, 'date': datetime.datetime(2012, 10, 8, 0, 0), 'Hours': '15:00-15:59', 'days': 8, 'month': 10, 'hour': 15}
# {'': 160, 'Count_days': 6, 'date': datetime.datetime(2012, 10, 8, 0, 0), 'Hours': '16:00-16:59', 'days': 8, 'month': 10, 'hour': 16}
# {'': 161, 'Count_days': 6, 'date': datetime.datetime(2012, 10, 8, 0, 0), 'Hours': '17:00-17:59', 'days': 8, 'month': 10, 'hour': 17}
# {'': 162, 'Count_days': 6, 'date': datetime.datetime(2012, 10, 8, 0, 0), 'Hours': '18:00-18:59', 'days': 8, 'month': 10, 'hour': 18}
# {'': 163, 'Count_days': 6, 'date': datetime.datetime(2012, 10, 8, 0, 0), 'Hours': '19:00-19:59', 'days': 8, 'month': 10, 'hour': 19}
# {'': 164, 'Count_days': 6, 'date': datetime.datetime(2012, 10, 8, 0, 0), 'Hours': '20:00-20:59', 'days': 8, 'month': 10, 'hour': 20}
# {'': 165, 'Count_days': 6, 'date': datetime.datetime(2012, 10, 8, 0, 0), 'Hours': '21:00-21:59', 'days': 8, 'month': 10, 'hour': 21}
# {'': 166, 'Count_days': 6, 'date': datetime.datetime(2012, 10, 8, 0, 0), 'Hours': '22:00-22:59', 'days': 8, 'month': 10, 'hour': 22}
# {'': 167, 'Count_days': 6, 'date': datetime.datetime(2012, 10, 8, 0, 0), 'Hours': '23:00-23:59', 'days': 8, 'month': 10, 'hour': 23}
# {'': 168, 'Count_days': 7, 'date': datetime.datetime(2012, 10, 9, 0, 0), 'Hours': '00:00-00:59', 'days': 9, 'month': 10, 'hour': 0}
# {'': 169, 'Count_days': 7, 'date': datetime.datetime(2012, 10, 9, 0, 0), 'Hours': '01:00-01:59', 'days': 9, 'month': 10, 'hour': 1}
# {'': 170, 'Count_days': 7, 'date': datetime.datetime(2012, 10, 9, 0, 0), 'Hours': '02:00-02:59', 'days': 9, 'month': 10, 'hour': 2}
# {'': 171, 'Count_days': 7, 'date': datetime.datetime(2012, 10, 9, 0, 0), 'Hours': '03:00-03:59', 'days': 9, 'month': 10, 'hour': 3}
# {'': 172, 'Count_days': 7, 'date': datetime.datetime(2012, 10, 9, 0, 0), 'Hours': '04:00-04:59', 'days': 9, 'month': 10, 'hour': 4}
# {'': 173, 'Count_days': 7, 'date': datetime.datetime(2012, 10, 9, 0, 0), 'Hours': '05:00-05:59', 'days': 9, 'month': 10, 'hour': 5}
# {'': 174, 'Count_days': 7, 'date': datetime.datetime(2012, 10, 9, 0, 0), 'Hours': '06:00-06:59', 'days': 9, 'month': 10, 'hour': 6}
# {'': 175, 'Count_days': 7, 'date': datetime.datetime(2012, 10, 9, 0, 0), 'Hours': '07:00-07:59', 'days': 9, 'month': 10, 'hour': 7}
# {'': 176, 'Count_days': 7, 'date': datetime.datetime(2012, 10, 9, 0, 0), 'Hours': '08:00-08:59', 'days': 9, 'month': 10, 'hour': 8}
# {'': 177, 'Count_days': 7, 'date': datetime.datetime(2012, 10, 9, 0, 0), 'Hours': '09:00-09:59', 'days': 9, 'month': 10, 'hour': 9}
# {'': 178, 'Count_days': 7, 'date': datetime.datetime(2012, 10, 9, 0, 0), 'Hours': '10:00-10:59', 'days': 9, 'month': 10, 'hour': 10}
# {'': 179, 'Count_days': 7, 'date': datetime.datetime(2012, 10, 9, 0, 0), 'Hours': '11:00-11:59', 'days': 9, 'month': 10, 'hour': 11}
# {'': 180, 'Count_days': 7, 'date': datetime.datetime(2012, 10, 9, 0, 0), 'Hours': '12:00-12:59', 'days': 9, 'month': 10, 'hour': 12}
# {'': 181, 'Count_days': 7, 'date': datetime.datetime(2012, 10, 9, 0, 0), 'Hours': '13:00-13:59', 'days': 9, 'month': 10, 'hour': 13}
# {'': 182, 'Count_days': 7, 'date': datetime.datetime(2012, 10, 9, 0, 0), 'Hours': '14:00-14:59', 'days': 9, 'month': 10, 'hour': 14}
# {'': 183, 'Count_days': 7, 'date': datetime.datetime(2012, 10, 9, 0, 0), 'Hours': '15:00-15:59', 'days': 9, 'month': 10, 'hour': 15}
# {'': 184, 'Count_days': 7, 'date': datetime.datetime(2012, 10, 9, 0, 0), 'Hours': '16:00-16:59', 'days': 9, 'month': 10, 'hour': 16}
# {'': 185, 'Count_days': 7, 'date': datetime.datetime(2012, 10, 9, 0, 0), 'Hours': '17:00-17:59', 'days': 9, 'month': 10, 'hour': 17}
# {'': 186, 'Count_days': 7, 'date': datetime.datetime(2012, 10, 9, 0, 0), 'Hours': '18:00-18:59', 'days': 9, 'month': 10, 'hour': 18}
# {'': 187, 'Count_days': 7, 'date': datetime.datetime(2012, 10, 9, 0, 0), 'Hours': '19:00-19:59', 'days': 9, 'month': 10, 'hour': 19}
# {'': 188, 'Count_days': 7, 'date': datetime.datetime(2012, 10, 9, 0, 0), 'Hours': '20:00-20:59', 'days': 9, 'month': 10, 'hour': 20}
# {'': 189, 'Count_days': 7, 'date': datetime.datetime(2012, 10, 9, 0, 0), 'Hours': '21:00-21:59', 'days': 9, 'month': 10, 'hour': 21}
# {'': 190, 'Count_days': 7, 'date': datetime.datetime(2012, 10, 9, 0, 0), 'Hours': '22:00-22:59', 'days': 9, 'month': 10, 'hour': 22}
# {'': 191, 'Count_days': 7, 'date': datetime.datetime(2012, 10, 9, 0, 0), 'Hours': '23:00-23:59', 'days': 9, 'month': 10, 'hour': 23}
# {'': 192, 'Count_days': 8, 'date': datetime.datetime(2012, 10, 10, 0, 0), 'Hours': '00:00-00:59', 'days': 10, 'month': 10, 'hour': 0}
# {'': 193, 'Count_days': 8, 'date': datetime.datetime(2012, 10, 10, 0, 0), 'Hours': '01:00-01:59', 'days': 10, 'month': 10, 'hour': 1}
# {'': 194, 'Count_days': 8, 'date': datetime.datetime(2012, 10, 10, 0, 0), 'Hours': '02:00-02:59', 'days': 10, 'month': 10, 'hour': 2}
# {'': 195, 'Count_days': 8, 'date': datetime.datetime(2012, 10, 10, 0, 0), 'Hours': '03:00-03:59', 'days': 10, 'month': 10, 'hour': 3}
# {'': 196, 'Count_days': 8, 'date': datetime.datetime(2012, 10, 10, 0, 0), 'Hours': '04:00-04:59', 'days': 10, 'month': 10, 'hour': 4}
# {'': 197, 'Count_days': 8, 'date': datetime.datetime(2012, 10, 10, 0, 0), 'Hours': '05:00-05:59', 'days': 10, 'month': 10, 'hour': 5}
# {'': 198, 'Count_days': 8, 'date': datetime.datetime(2012, 10, 10, 0, 0), 'Hours': '06:00-06:59', 'days': 10, 'month': 10, 'hour': 6}
# {'': 199, 'Count_days': 8, 'date': datetime.datetime(2012, 10, 10, 0, 0), 'Hours': '07:00-07:59', 'days': 10, 'month': 10, 'hour': 7}
# {'': 200, 'Count_days': 8, 'date': datetime.datetime(2012, 10, 10, 0, 0), 'Hours': '08:00-08:59', 'days': 10, 'month': 10, 'hour': 8}
# {'': 201, 'Count_days': 8, 'date': datetime.datetime(2012, 10, 10, 0, 0), 'Hours': '09:00-09:59', 'days': 10, 'month': 10, 'hour': 9}
# {'': 202, 'Count_days': 8, 'date': datetime.datetime(2012, 10, 10, 0, 0), 'Hours': '10:00-10:59', 'days': 10, 'month': 10, 'hour': 10}
# {'': 203, 'Count_days': 8, 'date': datetime.datetime(2012, 10, 10, 0, 0), 'Hours': '11:00-11:59', 'days': 10, 'month': 10, 'hour': 11}
# {'': 204, 'Count_days': 8, 'date': datetime.datetime(2012, 10, 10, 0, 0), 'Hours': '12:00-12:59', 'days': 10, 'month': 10, 'hour': 12}
# {'': 205, 'Count_days': 8, 'date': datetime.datetime(2012, 10, 10, 0, 0), 'Hours': '13:00-13:59', 'days': 10, 'month': 10, 'hour': 13}
# {'': 206, 'Count_days': 8, 'date': datetime.datetime(2012, 10, 10, 0, 0), 'Hours': '14:00-14:59', 'days': 10, 'month': 10, 'hour': 14}
# {'': 207, 'Count_days': 8, 'date': datetime.datetime(2012, 10, 10, 0, 0), 'Hours': '15:00-15:59', 'days': 10, 'month': 10, 'hour': 15}
# {'': 208, 'Count_days': 8, 'date': datetime.datetime(2012, 10, 10, 0, 0), 'Hours': '16:00-16:59', 'days': 10, 'month': 10, 'hour': 16}
# {'': 209, 'Count_days': 8, 'date': datetime.datetime(2012, 10, 10, 0, 0), 'Hours': '17:00-17:59', 'days': 10, 'month': 10, 'hour': 17}
# {'': 210, 'Count_days': 8, 'date': datetime.datetime(2012, 10, 10, 0, 0), 'Hours': '18:00-18:59', 'days': 10, 'month': 10, 'hour': 18}
# {'': 211, 'Count_days': 8, 'date': datetime.datetime(2012, 10, 10, 0, 0), 'Hours': '19:00-19:59', 'days': 10, 'month': 10, 'hour': 19}
# {'': 212, 'Count_days': 8, 'date': datetime.datetime(2012, 10, 10, 0, 0), 'Hours': '20:00-20:59', 'days': 10, 'month': 10, 'hour': 20}
# {'': 213, 'Count_days': 8, 'date': datetime.datetime(2012, 10, 10, 0, 0), 'Hours': '21:00-21:59', 'days': 10, 'month': 10, 'hour': 21}
# {'': 214, 'Count_days': 8, 'date': datetime.datetime(2012, 10, 10, 0, 0), 'Hours': '22:00-22:59', 'days': 10, 'month': 10, 'hour': 22}
# {'': 215, 'Count_days': 8, 'date': datetime.datetime(2012, 10, 10, 0, 0), 'Hours': '23:00-23:59', 'days': 10, 'month': 10, 'hour': 23}
# {'': 216, 'Count_days': 9, 'date': datetime.datetime(2012, 10, 11, 0, 0), 'Hours': '00:00-00:59', 'days': 11, 'month': 10, 'hour': 0}
# {'': 217, 'Count_days': 9, 'date': datetime.datetime(2012, 10, 11, 0, 0), 'Hours': '01:00-01:59', 'days': 11, 'month': 10, 'hour': 1}
# {'': 218, 'Count_days': 9, 'date': datetime.datetime(2012, 10, 11, 0, 0), 'Hours': '02:00-02:59', 'days': 11, 'month': 10, 'hour': 2}
# {'': 219, 'Count_days': 9, 'date': datetime.datetime(2012, 10, 11, 0, 0), 'Hours': '03:00-03:59', 'days': 11, 'month': 10, 'hour': 3}
# {'': 220, 'Count_days': 9, 'date': datetime.datetime(2012, 10, 11, 0, 0), 'Hours': '04:00-04:59', 'days': 11, 'month': 10, 'hour': 4}
# {'': 221, 'Count_days': 9, 'date': datetime.datetime(2012, 10, 11, 0, 0), 'Hours': '05:00-05:59', 'days': 11, 'month': 10, 'hour': 5}
# {'': 222, 'Count_days': 9, 'date': datetime.datetime(2012, 10, 11, 0, 0), 'Hours': '06:00-06:59', 'days': 11, 'month': 10, 'hour': 6}
# {'': 223, 'Count_days': 9, 'date': datetime.datetime(2012, 10, 11, 0, 0), 'Hours': '07:00-07:59', 'days': 11, 'month': 10, 'hour': 7}
# {'': 224, 'Count_days': 9, 'date': datetime.datetime(2012, 10, 11, 0, 0), 'Hours': '08:00-08:59', 'days': 11, 'month': 10, 'hour': 8}
# {'': 225, 'Count_days': 9, 'date': datetime.datetime(2012, 10, 11, 0, 0), 'Hours': '09:00-09:59', 'days': 11, 'month': 10, 'hour': 9}
# {'': 226, 'Count_days': 9, 'date': datetime.datetime(2012, 10, 11, 0, 0), 'Hours': '10:00-10:59', 'days': 11, 'month': 10, 'hour': 10}
# {'': 227, 'Count_days': 9, 'date': datetime.datetime(2012, 10, 11, 0, 0), 'Hours': '11:00-11:59', 'days': 11, 'month': 10, 'hour': 11}
# {'': 228, 'Count_days': 9, 'date': datetime.datetime(2012, 10, 11, 0, 0), 'Hours': '12:00-12:59', 'days': 11, 'month': 10, 'hour': 12}
# {'': 229, 'Count_days': 9, 'date': datetime.datetime(2012, 10, 11, 0, 0), 'Hours': '13:00-13:59', 'days': 11, 'month': 10, 'hour': 13}
# {'': 230, 'Count_days': 9, 'date': datetime.datetime(2012, 10, 11, 0, 0), 'Hours': '14:00-14:59', 'days': 11, 'month': 10, 'hour': 14}
# {'': 231, 'Count_days': 9, 'date': datetime.datetime(2012, 10, 11, 0, 0), 'Hours': '15:00-15:59', 'days': 11, 'month': 10, 'hour': 15}
# {'': 232, 'Count_days': 9, 'date': datetime.datetime(2012, 10, 11, 0, 0), 'Hours': '16:00-16:59', 'days': 11, 'month': 10, 'hour': 16}
# {'': 233, 'Count_days': 9, 'date': datetime.datetime(2012, 10, 11, 0, 0), 'Hours': '17:00-17:59', 'days': 11, 'month': 10, 'hour': 17}
# {'': 234, 'Count_days': 9, 'date': datetime.datetime(2012, 10, 11, 0, 0), 'Hours': '18:00-18:59', 'days': 11, 'month': 10, 'hour': 18}
# {'': 235, 'Count_days': 9, 'date': datetime.datetime(2012, 10, 11, 0, 0), 'Hours': '19:00-19:59', 'days': 11, 'month': 10, 'hour': 19}
# {'': 236, 'Count_days': 9, 'date': datetime.datetime(2012, 10, 11, 0, 0), 'Hours': '20:00-20:59', 'days': 11, 'month': 10, 'hour': 20}
# {'': 237, 'Count_days': 9, 'date': datetime.datetime(2012, 10, 11, 0, 0), 'Hours': '21:00-21:59', 'days': 11, 'month': 10, 'hour': 21}
# {'': 238, 'Count_days': 9, 'date': datetime.datetime(2012, 10, 11, 0, 0), 'Hours': '22:00-22:59', 'days': 11, 'month': 10, 'hour': 22}
# {'': 239, 'Count_days': 9, 'date': datetime.datetime(2012, 10, 11, 0, 0), 'Hours': '23:00-23:59', 'days': 11, 'month': 10, 'hour': 23}
# {'': 240, 'Count_days': 10, 'date': datetime.datetime(2012, 10, 12, 0, 0), 'Hours': '00:00-00:59', 'days': 12, 'month': 10, 'hour': 0}
# {'': 241, 'Count_days': 10, 'date': datetime.datetime(2012, 10, 12, 0, 0), 'Hours': '01:00-01:59', 'days': 12, 'month': 10, 'hour': 1}
# {'': 242, 'Count_days': 10, 'date': datetime.datetime(2012, 10, 12, 0, 0), 'Hours': '02:00-02:59', 'days': 12, 'month': 10, 'hour': 2}
# {'': 243, 'Count_days': 10, 'date': datetime.datetime(2012, 10, 12, 0, 0), 'Hours': '03:00-03:59', 'days': 12, 'month': 10, 'hour': 3}
# {'': 244, 'Count_days': 10, 'date': datetime.datetime(2012, 10, 12, 0, 0), 'Hours': '04:00-04:59', 'days': 12, 'month': 10, 'hour': 4}
# {'': 245, 'Count_days': 10, 'date': datetime.datetime(2012, 10, 12, 0, 0), 'Hours': '05:00-05:59', 'days': 12, 'month': 10, 'hour': 5}
# {'': 246, 'Count_days': 10, 'date': datetime.datetime(2012, 10, 12, 0, 0), 'Hours': '06:00-06:59', 'days': 12, 'month': 10, 'hour': 6}
# {'': 247, 'Count_days': 10, 'date': datetime.datetime(2012, 10, 12, 0, 0), 'Hours': '07:00-07:59', 'days': 12, 'month': 10, 'hour': 7}
# {'': 248, 'Count_days': 10, 'date': datetime.datetime(2012, 10, 12, 0, 0), 'Hours': '08:00-08:59', 'days': 12, 'month': 10, 'hour': 8}
# {'': 249, 'Count_days': 10, 'date': datetime.datetime(2012, 10, 12, 0, 0), 'Hours': '09:00-09:59', 'days': 12, 'month': 10, 'hour': 9}
# {'': 250, 'Count_days': 10, 'date': datetime.datetime(2012, 10, 12, 0, 0), 'Hours': '10:00-10:59', 'days': 12, 'month': 10, 'hour': 10}
# {'': 251, 'Count_days': 10, 'date': datetime.datetime(2012, 10, 12, 0, 0), 'Hours': '11:00-11:59', 'days': 12, 'month': 10, 'hour': 11}
# {'': 252, 'Count_days': 10, 'date': datetime.datetime(2012, 10, 12, 0, 0), 'Hours': '12:00-12:59', 'days': 12, 'month': 10, 'hour': 12}
# {'': 253, 'Count_days': 10, 'date': datetime.datetime(2012, 10, 12, 0, 0), 'Hours': '13:00-13:59', 'days': 12, 'month': 10, 'hour': 13}
# {'': 254, 'Count_days': 10, 'date': datetime.datetime(2012, 10, 12, 0, 0), 'Hours': '14:00-14:59', 'days': 12, 'month': 10, 'hour': 14}
# {'': 255, 'Count_days': 10, 'date': datetime.datetime(2012, 10, 12, 0, 0), 'Hours': '15:00-15:59', 'days': 12, 'month': 10, 'hour': 15}
# {'': 256, 'Count_days': 10, 'date': datetime.datetime(2012, 10, 12, 0, 0), 'Hours': '16:00-16:59', 'days': 12, 'month': 10, 'hour': 16}
# {'': 257, 'Count_days': 10, 'date': datetime.datetime(2012, 10, 12, 0, 0), 'Hours': '17:00-17:59', 'days': 12, 'month': 10, 'hour': 17}
# {'': 258, 'Count_days': 10, 'date': datetime.datetime(2012, 10, 12, 0, 0), 'Hours': '18:00-18:59', 'days': 12, 'month': 10, 'hour': 18}
# {'': 259, 'Count_days': 10, 'date': datetime.datetime(2012, 10, 12, 0, 0), 'Hours': '19:00-19:59', 'days': 12, 'month': 10, 'hour': 19}
# {'': 260, 'Count_days': 10, 'date': datetime.datetime(2012, 10, 12, 0, 0), 'Hours': '20:00-20:59', 'days': 12, 'month': 10, 'hour': 20}
# {'': 261, 'Count_days': 10, 'date': datetime.datetime(2012, 10, 12, 0, 0), 'Hours': '21:00-21:59', 'days': 12, 'month': 10, 'hour': 21}
# {'': 262, 'Count_days': 10, 'date': datetime.datetime(2012, 10, 12, 0, 0), 'Hours': '22:00-22:59', 'days': 12, 'month': 10, 'hour': 22}
# {'': 263, 'Count_days': 10, 'date': datetime.datetime(2012, 10, 12, 0, 0), 'Hours': '23:00-23:59', 'days': 12, 'month': 10, 'hour': 23}
# {'': 264, 'Count_days': 11, 'date': datetime.datetime(2012, 10, 13, 0, 0), 'Hours': '00:00-00:59', 'days': 13, 'month': 10, 'hour': 0}
# {'': 265, 'Count_days': 11, 'date': datetime.datetime(2012, 10, 13, 0, 0), 'Hours': '01:00-01:59', 'days': 13, 'month': 10, 'hour': 1}
# {'': 266, 'Count_days': 11, 'date': datetime.datetime(2012, 10, 13, 0, 0), 'Hours': '02:00-02:59', 'days': 13, 'month': 10, 'hour': 2}
# {'': 267, 'Count_days': 11, 'date': datetime.datetime(2012, 10, 13, 0, 0), 'Hours': '03:00-03:59', 'days': 13, 'month': 10, 'hour': 3}
# {'': 268, 'Count_days': 11, 'date': datetime.datetime(2012, 10, 13, 0, 0), 'Hours': '04:00-04:59', 'days': 13, 'month': 10, 'hour': 4}
# {'': 269, 'Count_days': 11, 'date': datetime.datetime(2012, 10, 13, 0, 0), 'Hours': '05:00-05:59', 'days': 13, 'month': 10, 'hour': 5}
# {'': 270, 'Count_days': 11, 'date': datetime.datetime(2012, 10, 13, 0, 0), 'Hours': '06:00-06:59', 'days': 13, 'month': 10, 'hour': 6}
# {'': 271, 'Count_days': 11, 'date': datetime.datetime(2012, 10, 13, 0, 0), 'Hours': '07:00-07:59', 'days': 13, 'month': 10, 'hour': 7}
# {'': 272, 'Count_days': 11, 'date': datetime.datetime(2012, 10, 13, 0, 0), 'Hours': '08:00-08:59', 'days': 13, 'month': 10, 'hour': 8}
# {'': 273, 'Count_days': 11, 'date': datetime.datetime(2012, 10, 13, 0, 0), 'Hours': '09:00-09:59', 'days': 13, 'month': 10, 'hour': 9}
# {'': 274, 'Count_days': 11, 'date': datetime.datetime(2012, 10, 13, 0, 0), 'Hours': '10:00-10:59', 'days': 13, 'month': 10, 'hour': 10}
# {'': 275, 'Count_days': 11, 'date': datetime.datetime(2012, 10, 13, 0, 0), 'Hours': '11:00-11:59', 'days': 13, 'month': 10, 'hour': 11}
# {'': 276, 'Count_days': 11, 'date': datetime.datetime(2012, 10, 13, 0, 0), 'Hours': '12:00-12:59', 'days': 13, 'month': 10, 'hour': 12}
# {'': 277, 'Count_days': 11, 'date': datetime.datetime(2012, 10, 13, 0, 0), 'Hours': '13:00-13:59', 'days': 13, 'month': 10, 'hour': 13}
# {'': 278, 'Count_days': 11, 'date': datetime.datetime(2012, 10, 13, 0, 0), 'Hours': '14:00-14:59', 'days': 13, 'month': 10, 'hour': 14}
# {'': 279, 'Count_days': 11, 'date': datetime.datetime(2012, 10, 13, 0, 0), 'Hours': '15:00-15:59', 'days': 13, 'month': 10, 'hour': 15}
# {'': 280, 'Count_days': 11, 'date': datetime.datetime(2012, 10, 13, 0, 0), 'Hours': '16:00-16:59', 'days': 13, 'month': 10, 'hour': 16}
# {'': 281, 'Count_days': 11, 'date': datetime.datetime(2012, 10, 13, 0, 0), 'Hours': '17:00-17:59', 'days': 13, 'month': 10, 'hour': 17}
# {'': 282, 'Count_days': 11, 'date': datetime.datetime(2012, 10, 13, 0, 0), 'Hours': '18:00-18:59', 'days': 13, 'month': 10, 'hour': 18}
# {'': 283, 'Count_days': 11, 'date': datetime.datetime(2012, 10, 13, 0, 0), 'Hours': '19:00-19:59', 'days': 13, 'month': 10, 'hour': 19}
# {'': 284, 'Count_days': 11, 'date': datetime.datetime(2012, 10, 13, 0, 0), 'Hours': '20:00-20:59', 'days': 13, 'month': 10, 'hour': 20}
# {'': 285, 'Count_days': 11, 'date': datetime.datetime(2012, 10, 13, 0, 0), 'Hours': '21:00-21:59', 'days': 13, 'month': 10, 'hour': 21}
# {'': 286, 'Count_days': 11, 'date': datetime.datetime(2012, 10, 13, 0, 0), 'Hours': '22:00-22:59', 'days': 13, 'month': 10, 'hour': 22}
# {'': 287, 'Count_days': 11, 'date': datetime.datetime(2012, 10, 13, 0, 0), 'Hours': '23:00-23:59', 'days': 13, 'month': 10, 'hour': 23}
# {'': 288, 'Count_days': 12, 'date': datetime.datetime(2012, 10, 14, 0, 0), 'Hours': '00:00-00:59', 'days': 14, 'month': 10, 'hour': 0}
# {'': 289, 'Count_days': 12, 'date': datetime.datetime(2012, 10, 14, 0, 0), 'Hours': '01:00-01:59', 'days': 14, 'month': 10, 'hour': 1}
# {'': 290, 'Count_days': 12, 'date': datetime.datetime(2012, 10, 14, 0, 0), 'Hours': '02:00-02:59', 'days': 14, 'month': 10, 'hour': 2}
# {'': 291, 'Count_days': 12, 'date': datetime.datetime(2012, 10, 14, 0, 0), 'Hours': '03:00-03:59', 'days': 14, 'month': 10, 'hour': 3}
# {'': 292, 'Count_days': 12, 'date': datetime.datetime(2012, 10, 14, 0, 0), 'Hours': '04:00-04:59', 'days': 14, 'month': 10, 'hour': 4}
# {'': 293, 'Count_days': 12, 'date': datetime.datetime(2012, 10, 14, 0, 0), 'Hours': '05:00-05:59', 'days': 14, 'month': 10, 'hour': 5}
# {'': 294, 'Count_days': 12, 'date': datetime.datetime(2012, 10, 14, 0, 0), 'Hours': '06:00-06:59', 'days': 14, 'month': 10, 'hour': 6}
# {'': 295, 'Count_days': 12, 'date': datetime.datetime(2012, 10, 14, 0, 0), 'Hours': '07:00-07:59', 'days': 14, 'month': 10, 'hour': 7}
# {'': 296, 'Count_days': 12, 'date': datetime.datetime(2012, 10, 14, 0, 0), 'Hours': '08:00-08:59', 'days': 14, 'month': 10, 'hour': 8}
# {'': 297, 'Count_days': 12, 'date': datetime.datetime(2012, 10, 14, 0, 0), 'Hours': '09:00-09:59', 'days': 14, 'month': 10, 'hour': 9}
# {'': 298, 'Count_days': 12, 'date': datetime.datetime(2012, 10, 14, 0, 0), 'Hours': '10:00-10:59', 'days': 14, 'month': 10, 'hour': 10}
# {'': 299, 'Count_days': 12, 'date': datetime.datetime(2012, 10, 14, 0, 0), 'Hours': '11:00-11:59', 'days': 14, 'month': 10, 'hour': 11}
# {'': 300, 'Count_days': 12, 'date': datetime.datetime(2012, 10, 14, 0, 0), 'Hours': '12:00-12:59', 'days': 14, 'month': 10, 'hour': 12}
# {'': 301, 'Count_days': 12, 'date': datetime.datetime(2012, 10, 14, 0, 0), 'Hours': '13:00-13:59', 'days': 14, 'month': 10, 'hour': 13}
# {'': 302, 'Count_days': 12, 'date': datetime.datetime(2012, 10, 14, 0, 0), 'Hours': '14:00-14:59', 'days': 14, 'month': 10, 'hour': 14}
# {'': 303, 'Count_days': 12, 'date': datetime.datetime(2012, 10, 14, 0, 0), 'Hours': '15:00-15:59', 'days': 14, 'month': 10, 'hour': 15}
# {'': 304, 'Count_days': 12, 'date': datetime.datetime(2012, 10, 14, 0, 0), 'Hours': '16:00-16:59', 'days': 14, 'month': 10, 'hour': 16}
# {'': 305, 'Count_days': 12, 'date': datetime.datetime(2012, 10, 14, 0, 0), 'Hours': '17:00-17:59', 'days': 14, 'month': 10, 'hour': 17}
# {'': 306, 'Count_days': 12, 'date': datetime.datetime(2012, 10, 14, 0, 0), 'Hours': '18:00-18:59', 'days': 14, 'month': 10, 'hour': 18}
# {'': 307, 'Count_days': 12, 'date': datetime.datetime(2012, 10, 14, 0, 0), 'Hours': '19:00-19:59', 'days': 14, 'month': 10, 'hour': 19}
# {'': 308, 'Count_days': 12, 'date': datetime.datetime(2012, 10, 14, 0, 0), 'Hours': '20:00-20:59', 'days': 14, 'month': 10, 'hour': 20}
# {'': 309, 'Count_days': 12, 'date': datetime.datetime(2012, 10, 14, 0, 0), 'Hours': '21:00-21:59', 'days': 14, 'month': 10, 'hour': 21}
# {'': 310, 'Count_days': 12, 'date': datetime.datetime(2012, 10, 14, 0, 0), 'Hours': '22:00-22:59', 'days': 14, 'month': 10, 'hour': 22}
# {'': 311, 'Count_days': 12, 'date': datetime.datetime(2012, 10, 14, 0, 0), 'Hours': '23:00-23:59', 'days': 14, 'month': 10, 'hour': 23}
# {'': 312, 'Count_days': 13, 'date': datetime.datetime(2012, 10, 15, 0, 0), 'Hours': '00:00-00:59', 'days': 15, 'month': 10, 'hour': 0}
# {'': 313, 'Count_days': 13, 'date': datetime.datetime(2012, 10, 15, 0, 0), 'Hours': '01:00-01:59', 'days': 15, 'month': 10, 'hour': 1}
# {'': 314, 'Count_days': 13, 'date': datetime.datetime(2012, 10, 15, 0, 0), 'Hours': '02:00-02:59', 'days': 15, 'month': 10, 'hour': 2}
# {'': 315, 'Count_days': 13, 'date': datetime.datetime(2012, 10, 15, 0, 0), 'Hours': '03:00-03:59', 'days': 15, 'month': 10, 'hour': 3}
# {'': 316, 'Count_days': 13, 'date': datetime.datetime(2012, 10, 15, 0, 0), 'Hours': '04:00-04:59', 'days': 15, 'month': 10, 'hour': 4}
# {'': 317, 'Count_days': 13, 'date': datetime.datetime(2012, 10, 15, 0, 0), 'Hours': '05:00-05:59', 'days': 15, 'month': 10, 'hour': 5}
# {'': 318, 'Count_days': 13, 'date': datetime.datetime(2012, 10, 15, 0, 0), 'Hours': '06:00-06:59', 'days': 15, 'month': 10, 'hour': 6}
# {'': 319, 'Count_days': 13, 'date': datetime.datetime(2012, 10, 15, 0, 0), 'Hours': '07:00-07:59', 'days': 15, 'month': 10, 'hour': 7}
# {'': 320, 'Count_days': 13, 'date': datetime.datetime(2012, 10, 15, 0, 0), 'Hours': '08:00-08:59', 'days': 15, 'month': 10, 'hour': 8}
# {'': 321, 'Count_days': 13, 'date': datetime.datetime(2012, 10, 15, 0, 0), 'Hours': '09:00-09:59', 'days': 15, 'month': 10, 'hour': 9}
# {'': 322, 'Count_days': 13, 'date': datetime.datetime(2012, 10, 15, 0, 0), 'Hours': '10:00-10:59', 'days': 15, 'month': 10, 'hour': 10}
# {'': 323, 'Count_days': 13, 'date': datetime.datetime(2012, 10, 15, 0, 0), 'Hours': '11:00-11:59', 'days': 15, 'month': 10, 'hour': 11}
# {'': 324, 'Count_days': 13, 'date': datetime.datetime(2012, 10, 15, 0, 0), 'Hours': '12:00-12:59', 'days': 15, 'month': 10, 'hour': 12}
# {'': 325, 'Count_days': 13, 'date': datetime.datetime(2012, 10, 15, 0, 0), 'Hours': '13:00-13:59', 'days': 15, 'month': 10, 'hour': 13}
# {'': 326, 'Count_days': 13, 'date': datetime.datetime(2012, 10, 15, 0, 0), 'Hours': '14:00-14:59', 'days': 15, 'month': 10, 'hour': 14}
# {'': 327, 'Count_days': 13, 'date': datetime.datetime(2012, 10, 15, 0, 0), 'Hours': '15:00-15:59', 'days': 15, 'month': 10, 'hour': 15}
# {'': 328, 'Count_days': 13, 'date': datetime.datetime(2012, 10, 15, 0, 0), 'Hours': '16:00-16:59', 'days': 15, 'month': 10, 'hour': 16}
# {'': 329, 'Count_days': 13, 'date': datetime.datetime(2012, 10, 15, 0, 0), 'Hours': '17:00-17:59', 'days': 15, 'month': 10, 'hour': 17}
# {'': 330, 'Count_days': 13, 'date': datetime.datetime(2012, 10, 15, 0, 0), 'Hours': '18:00-18:59', 'days': 15, 'month': 10, 'hour': 18}
# {'': 331, 'Count_days': 13, 'date': datetime.datetime(2012, 10, 15, 0, 0), 'Hours': '19:00-19:59', 'days': 15, 'month': 10, 'hour': 19}
# {'': 332, 'Count_days': 13, 'date': datetime.datetime(2012, 10, 15, 0, 0), 'Hours': '20:00-20:59', 'days': 15, 'month': 10, 'hour': 20}
# {'': 333, 'Count_days': 13, 'date': datetime.datetime(2012, 10, 15, 0, 0), 'Hours': '21:00-21:59', 'days': 15, 'month': 10, 'hour': 21}
# {'': 334, 'Count_days': 13, 'date': datetime.datetime(2012, 10, 15, 0, 0), 'Hours': '22:00-22:59', 'days': 15, 'month': 10, 'hour': 22}
# {'': 335, 'Count_days': 13, 'date': datetime.datetime(2012, 10, 15, 0, 0), 'Hours': '23:00-23:59', 'days': 15, 'month': 10, 'hour': 23}
# {'': 336, 'Count_days': 14, 'date': datetime.datetime(2012, 10, 16, 0, 0), 'Hours': '00:00-00:59', 'days': 16, 'month': 10, 'hour': 0}
# {'': 337, 'Count_days': 14, 'date': datetime.datetime(2012, 10, 16, 0, 0), 'Hours': '01:00-01:59', 'days': 16, 'month': 10, 'hour': 1}
# {'': 338, 'Count_days': 14, 'date': datetime.datetime(2012, 10, 16, 0, 0), 'Hours': '02:00-02:59', 'days': 16, 'month': 10, 'hour': 2}
# {'': 339, 'Count_days': 14, 'date': datetime.datetime(2012, 10, 16, 0, 0), 'Hours': '03:00-03:59', 'days': 16, 'month': 10, 'hour': 3}
# {'': 340, 'Count_days': 14, 'date': datetime.datetime(2012, 10, 16, 0, 0), 'Hours': '04:00-04:59', 'days': 16, 'month': 10, 'hour': 4}
# {'': 341, 'Count_days': 14, 'date': datetime.datetime(2012, 10, 16, 0, 0), 'Hours': '05:00-05:59', 'days': 16, 'month': 10, 'hour': 5}
# {'': 342, 'Count_days': 14, 'date': datetime.datetime(2012, 10, 16, 0, 0), 'Hours': '06:00-06:59', 'days': 16, 'month': 10, 'hour': 6}
# {'': 343, 'Count_days': 14, 'date': datetime.datetime(2012, 10, 16, 0, 0), 'Hours': '07:00-07:59', 'days': 16, 'month': 10, 'hour': 7}
# {'': 344, 'Count_days': 14, 'date': datetime.datetime(2012, 10, 16, 0, 0), 'Hours': '08:00-08:59', 'days': 16, 'month': 10, 'hour': 8}
# {'': 345, 'Count_days': 14, 'date': datetime.datetime(2012, 10, 16, 0, 0), 'Hours': '09:00-09:59', 'days': 16, 'month': 10, 'hour': 9}
# {'': 346, 'Count_days': 14, 'date': datetime.datetime(2012, 10, 16, 0, 0), 'Hours': '10:00-10:59', 'days': 16, 'month': 10, 'hour': 10}
# {'': 347, 'Count_days': 14, 'date': datetime.datetime(2012, 10, 16, 0, 0), 'Hours': '11:00-11:59', 'days': 16, 'month': 10, 'hour': 11}
# {'': 348, 'Count_days': 14, 'date': datetime.datetime(2012, 10, 16, 0, 0), 'Hours': '12:00-12:59', 'days': 16, 'month': 10, 'hour': 12}
# {'': 349, 'Count_days': 14, 'date': datetime.datetime(2012, 10, 16, 0, 0), 'Hours': '13:00-13:59', 'days': 16, 'month': 10, 'hour': 13}
# {'': 350, 'Count_days': 14, 'date': datetime.datetime(2012, 10, 16, 0, 0), 'Hours': '14:00-14:59', 'days': 16, 'month': 10, 'hour': 14}
# {'': 351, 'Count_days': 14, 'date': datetime.datetime(2012, 10, 16, 0, 0), 'Hours': '15:00-15:59', 'days': 16, 'month': 10, 'hour': 15}
# {'': 352, 'Count_days': 14, 'date': datetime.datetime(2012, 10, 16, 0, 0), 'Hours': '16:00-16:59', 'days': 16, 'month': 10, 'hour': 16}
# {'': 353, 'Count_days': 14, 'date': datetime.datetime(2012, 10, 16, 0, 0), 'Hours': '17:00-17:59', 'days': 16, 'month': 10, 'hour': 17}
# {'': 354, 'Count_days': 14, 'date': datetime.datetime(2012, 10, 16, 0, 0), 'Hours': '18:00-18:59', 'days': 16, 'month': 10, 'hour': 18}
# {'': 355, 'Count_days': 14, 'date': datetime.datetime(2012, 10, 16, 0, 0), 'Hours': '19:00-19:59', 'days': 16, 'month': 10, 'hour': 19}
# {'': 356, 'Count_days': 14, 'date': datetime.datetime(2012, 10, 16, 0, 0), 'Hours': '20:00-20:59', 'days': 16, 'month': 10, 'hour': 20}
# {'': 357, 'Count_days': 14, 'date': datetime.datetime(2012, 10, 16, 0, 0), 'Hours': '21:00-21:59', 'days': 16, 'month': 10, 'hour': 21}
# {'': 358, 'Count_days': 14, 'date': datetime.datetime(2012, 10, 16, 0, 0), 'Hours': '22:00-22:59', 'days': 16, 'month': 10, 'hour': 22}
# ...
# {'': 8378, 'Count_days': 349, 'date': datetime.datetime(2013, 9, 26, 0, 0), 'Hours': '02:00-02:59', 'days': 26, 'month': 9, 'hour': 2}
# {'': 8379, 'Count_days': 349, 'date': datetime.datetime(2013, 9, 26, 0, 0), 'Hours': '03:00-03:59', 'days': 26, 'month': 9, 'hour': 3}
# {'': 8380, 'Count_days': 349, 'date': datetime.datetime(2013, 9, 26, 0, 0), 'Hours': '04:00-04:59', 'days': 26, 'month': 9, 'hour': 4}
# {'': 8381, 'Count_days': 349, 'date': datetime.datetime(2013, 9, 26, 0, 0), 'Hours': '05:00-05:59', 'days': 26, 'month': 9, 'hour': 5}
# {'': 8382, 'Count_days': 349, 'date': datetime.datetime(2013, 9, 26, 0, 0), 'Hours': '06:00-06:59', 'days': 26, 'month': 9, 'hour': 6}
# {'': 8383, 'Count_days': 349, 'date': datetime.datetime(2013, 9, 26, 0, 0), 'Hours': '07:00-07:59', 'days': 26, 'month': 9, 'hour': 7}
# {'': 8384, 'Count_days': 349, 'date': datetime.datetime(2013, 9, 26, 0, 0), 'Hours': '08:00-08:59', 'days': 26, 'month': 9, 'hour': 8}
# {'': 8385, 'Count_days': 349, 'date': datetime.datetime(2013, 9, 26, 0, 0), 'Hours': '09:00-09:59', 'days': 26, 'month': 9, 'hour': 9}
# {'': 8386, 'Count_days': 349, 'date': datetime.datetime(2013, 9, 26, 0, 0), 'Hours': '10:00-10:59', 'days': 26, 'month': 9, 'hour': 10}
# {'': 8387, 'Count_days': 349, 'date': datetime.datetime(2013, 9, 26, 0, 0), 'Hours': '11:00-11:59', 'days': 26, 'month': 9, 'hour': 11}
# {'': 8388, 'Count_days': 349, 'date': datetime.datetime(2013, 9, 26, 0, 0), 'Hours': '12:00-12:59', 'days': 26, 'month': 9, 'hour': 12}
# {'': 8389, 'Count_days': 349, 'date': datetime.datetime(2013, 9, 26, 0, 0), 'Hours': '13:00-13:59', 'days': 26, 'month': 9, 'hour': 13}
# {'': 8390, 'Count_days': 349, 'date': datetime.datetime(2013, 9, 26, 0, 0), 'Hours': '14:00-14:59', 'days': 26, 'month': 9, 'hour': 14}
# {'': 8391, 'Count_days': 349, 'date': datetime.datetime(2013, 9, 26, 0, 0), 'Hours': '15:00-15:59', 'days': 26, 'month': 9, 'hour': 15}
# {'': 8392, 'Count_days': 349, 'date': datetime.datetime(2013, 9, 26, 0, 0), 'Hours': '16:00-16:59', 'days': 26, 'month': 9, 'hour': 16}
# {'': 8393, 'Count_days': 349, 'date': datetime.datetime(2013, 9, 26, 0, 0), 'Hours': '17:00-17:59', 'days': 26, 'month': 9, 'hour': 17}
# {'': 8394, 'Count_days': 349, 'date': datetime.datetime(2013, 9, 26, 0, 0), 'Hours': '18:00-18:59', 'days': 26, 'month': 9, 'hour': 18}
# {'': 8395, 'Count_days': 349, 'date': datetime.datetime(2013, 9, 26, 0, 0), 'Hours': '19:00-19:59', 'days': 26, 'month': 9, 'hour': 19}
# {'': 8396, 'Count_days': 349, 'date': datetime.datetime(2013, 9, 26, 0, 0), 'Hours': '20:00-20:59', 'days': 26, 'month': 9, 'hour': 20}
# {'': 8397, 'Count_days': 349, 'date': datetime.datetime(2013, 9, 26, 0, 0), 'Hours': '21:00-21:59', 'days': 26, 'month': 9, 'hour': 21}
# {'': 8398, 'Count_days': 349, 'date': datetime.datetime(2013, 9, 26, 0, 0), 'Hours': '22:00-22:59', 'days': 26, 'month': 9, 'hour': 22}
# {'': 8399, 'Count_days': 349, 'date': datetime.datetime(2013, 9, 26, 0, 0), 'Hours': '23:00-23:59', 'days': 26, 'month': 9, 'hour': 23}
# {'': 8400, 'Count_days': 350, 'date': datetime.datetime(2013, 9, 27, 0, 0), 'Hours': '00:00-00:59', 'days': 27, 'month': 9, 'hour': 0}
# {'': 8401, 'Count_days': 350, 'date': datetime.datetime(2013, 9, 27, 0, 0), 'Hours': '01:00-01:59', 'days': 27, 'month': 9, 'hour': 1}
# {'': 8402, 'Count_days': 350, 'date': datetime.datetime(2013, 9, 27, 0, 0), 'Hours': '02:00-02:59', 'days': 27, 'month': 9, 'hour': 2}
# {'': 8403, 'Count_days': 350, 'date': datetime.datetime(2013, 9, 27, 0, 0), 'Hours': '03:00-03:59', 'days': 27, 'month': 9, 'hour': 3}
# {'': 8404, 'Count_days': 350, 'date': datetime.datetime(2013, 9, 27, 0, 0), 'Hours': '04:00-04:59', 'days': 27, 'month': 9, 'hour': 4}
# {'': 8405, 'Count_days': 350, 'date': datetime.datetime(2013, 9, 27, 0, 0), 'Hours': '05:00-05:59', 'days': 27, 'month': 9, 'hour': 5}
# {'': 8406, 'Count_days': 350, 'date': datetime.datetime(2013, 9, 27, 0, 0), 'Hours': '06:00-06:59', 'days': 27, 'month': 9, 'hour': 6}
# {'': 8407, 'Count_days': 350, 'date': datetime.datetime(2013, 9, 27, 0, 0), 'Hours': '07:00-07:59', 'days': 27, 'month': 9, 'hour': 7}
# {'': 8408, 'Count_days': 350, 'date': datetime.datetime(2013, 9, 27, 0, 0), 'Hours': '08:00-08:59', 'days': 27, 'month': 9, 'hour': 8}
# {'': 8409, 'Count_days': 350, 'date': datetime.datetime(2013, 9, 27, 0, 0), 'Hours': '09:00-09:59', 'days': 27, 'month': 9, 'hour': 9}
# {'': 8410, 'Count_days': 350, 'date': datetime.datetime(2013, 9, 27, 0, 0), 'Hours': '10:00-10:59', 'days': 27, 'month': 9, 'hour': 10}
# {'': 8411, 'Count_days': 350, 'date': datetime.datetime(2013, 9, 27, 0, 0), 'Hours': '11:00-11:59', 'days': 27, 'month': 9, 'hour': 11}
# {'': 8412, 'Count_days': 350, 'date': datetime.datetime(2013, 9, 27, 0, 0), 'Hours': '12:00-12:59', 'days': 27, 'month': 9, 'hour': 12}
# {'': 8413, 'Count_days': 350, 'date': datetime.datetime(2013, 9, 27, 0, 0), 'Hours': '13:00-13:59', 'days': 27, 'month': 9, 'hour': 13}
# {'': 8414, 'Count_days': 350, 'date': datetime.datetime(2013, 9, 27, 0, 0), 'Hours': '14:00-14:59', 'days': 27, 'month': 9, 'hour': 14}
# {'': 8415, 'Count_days': 350, 'date': datetime.datetime(2013, 9, 27, 0, 0), 'Hours': '15:00-15:59', 'days': 27, 'month': 9, 'hour': 15}
# {'': 8416, 'Count_days': 350, 'date': datetime.datetime(2013, 9, 27, 0, 0), 'Hours': '16:00-16:59', 'days': 27, 'month': 9, 'hour': 16}
# {'': 8417, 'Count_days': 350, 'date': datetime.datetime(2013, 9, 27, 0, 0), 'Hours': '17:00-17:59', 'days': 27, 'month': 9, 'hour': 17}
# {'': 8418, 'Count_days': 350, 'date': datetime.datetime(2013, 9, 27, 0, 0), 'Hours': '18:00-18:59', 'days': 27, 'month': 9, 'hour': 18}
# {'': 8419, 'Count_days': 350, 'date': datetime.datetime(2013, 9, 27, 0, 0), 'Hours': '19:00-19:59', 'days': 27, 'month': 9, 'hour': 19}
# {'': 8420, 'Count_days': 350, 'date': datetime.datetime(2013, 9, 27, 0, 0), 'Hours': '20:00-20:59', 'days': 27, 'month': 9, 'hour': 20}
# {'': 8421, 'Count_days': 350, 'date': datetime.datetime(2013, 9, 27, 0, 0), 'Hours': '21:00-21:59', 'days': 27, 'month': 9, 'hour': 21}
# {'': 8422, 'Count_days': 350, 'date': datetime.datetime(2013, 9, 27, 0, 0), 'Hours': '22:00-22:59', 'days': 27, 'month': 9, 'hour': 22}
# {'': 8423, 'Count_days': 350, 'date': datetime.datetime(2013, 9, 27, 0, 0), 'Hours': '23:00-23:59', 'days': 27, 'month': 9, 'hour': 23}
# {'': 8424, 'Count_days': 351, 'date': datetime.datetime(2013, 9, 28, 0, 0), 'Hours': '00:00-00:59', 'days': 28, 'month': 9, 'hour': 0}
# {'': 8425, 'Count_days': 351, 'date': datetime.datetime(2013, 9, 28, 0, 0), 'Hours': '01:00-01:59', 'days': 28, 'month': 9, 'hour': 1}
# {'': 8426, 'Count_days': 351, 'date': datetime.datetime(2013, 9, 28, 0, 0), 'Hours': '02:00-02:59', 'days': 28, 'month': 9, 'hour': 2}
# {'': 8427, 'Count_days': 351, 'date': datetime.datetime(2013, 9, 28, 0, 0), 'Hours': '03:00-03:59', 'days': 28, 'month': 9, 'hour': 3}
# {'': 8428, 'Count_days': 351, 'date': datetime.datetime(2013, 9, 28, 0, 0), 'Hours': '04:00-04:59', 'days': 28, 'month': 9, 'hour': 4}
# {'': 8429, 'Count_days': 351, 'date': datetime.datetime(2013, 9, 28, 0, 0), 'Hours': '05:00-05:59', 'days': 28, 'month': 9, 'hour': 5}
# {'': 8430, 'Count_days': 351, 'date': datetime.datetime(2013, 9, 28, 0, 0), 'Hours': '06:00-06:59', 'days': 28, 'month': 9, 'hour': 6}
# {'': 8431, 'Count_days': 351, 'date': datetime.datetime(2013, 9, 28, 0, 0), 'Hours': '07:00-07:59', 'days': 28, 'month': 9, 'hour': 7}
# {'': 8432, 'Count_days': 351, 'date': datetime.datetime(2013, 9, 28, 0, 0), 'Hours': '08:00-08:59', 'days': 28, 'month': 9, 'hour': 8}
# {'': 8433, 'Count_days': 351, 'date': datetime.datetime(2013, 9, 28, 0, 0), 'Hours': '09:00-09:59', 'days': 28, 'month': 9, 'hour': 9}
# {'': 8434, 'Count_days': 351, 'date': datetime.datetime(2013, 9, 28, 0, 0), 'Hours': '10:00-10:59', 'days': 28, 'month': 9, 'hour': 10}
# {'': 8435, 'Count_days': 351, 'date': datetime.datetime(2013, 9, 28, 0, 0), 'Hours': '11:00-11:59', 'days': 28, 'month': 9, 'hour': 11}
# {'': 8436, 'Count_days': 351, 'date': datetime.datetime(2013, 9, 28, 0, 0), 'Hours': '12:00-12:59', 'days': 28, 'month': 9, 'hour': 12}
# {'': 8437, 'Count_days': 351, 'date': datetime.datetime(2013, 9, 28, 0, 0), 'Hours': '13:00-13:59', 'days': 28, 'month': 9, 'hour': 13}
# {'': 8438, 'Count_days': 351, 'date': datetime.datetime(2013, 9, 28, 0, 0), 'Hours': '14:00-14:59', 'days': 28, 'month': 9, 'hour': 14}
# {'': 8439, 'Count_days': 351, 'date': datetime.datetime(2013, 9, 28, 0, 0), 'Hours': '15:00-15:59', 'days': 28, 'month': 9, 'hour': 15}
# {'': 8440, 'Count_days': 351, 'date': datetime.datetime(2013, 9, 28, 0, 0), 'Hours': '16:00-16:59', 'days': 28, 'month': 9, 'hour': 16}
# {'': 8441, 'Count_days': 351, 'date': datetime.datetime(2013, 9, 28, 0, 0), 'Hours': '17:00-17:59', 'days': 28, 'month': 9, 'hour': 17}
# {'': 8442, 'Count_days': 351, 'date': datetime.datetime(2013, 9, 28, 0, 0), 'Hours': '18:00-18:59', 'days': 28, 'month': 9, 'hour': 18}
# {'': 8443, 'Count_days': 351, 'date': datetime.datetime(2013, 9, 28, 0, 0), 'Hours': '19:00-19:59', 'days': 28, 'month': 9, 'hour': 19}
# {'': 8444, 'Count_days': 351, 'date': datetime.datetime(2013, 9, 28, 0, 0), 'Hours': '20:00-20:59', 'days': 28, 'month': 9, 'hour': 20}
# {'': 8445, 'Count_days': 351, 'date': datetime.datetime(2013, 9, 28, 0, 0), 'Hours': '21:00-21:59', 'days': 28, 'month': 9, 'hour': 21}
# {'': 8446, 'Count_days': 351, 'date': datetime.datetime(2013, 9, 28, 0, 0), 'Hours': '22:00-22:59', 'days': 28, 'month': 9, 'hour': 22}
# {'': 8447, 'Count_days': 351, 'date': datetime.datetime(2013, 9, 28, 0, 0), 'Hours': '23:00-23:59', 'days': 28, 'month': 9, 'hour': 23}
# {'': 8448, 'Count_days': 352, 'date': datetime.datetime(2013, 9, 29, 0, 0), 'Hours': '00:00-00:59', 'days': 29, 'month': 9, 'hour': 0}
# {'': 8449, 'Count_days': 352, 'date': datetime.datetime(2013, 9, 29, 0, 0), 'Hours': '01:00-01:59', 'days': 29, 'month': 9, 'hour': 1}
# {'': 8450, 'Count_days': 352, 'date': datetime.datetime(2013, 9, 29, 0, 0), 'Hours': '02:00-02:59', 'days': 29, 'month': 9, 'hour': 2}
# {'': 8451, 'Count_days': 352, 'date': datetime.datetime(2013, 9, 29, 0, 0), 'Hours': '03:00-03:59', 'days': 29, 'month': 9, 'hour': 3}
# {'': 8452, 'Count_days': 352, 'date': datetime.datetime(2013, 9, 29, 0, 0), 'Hours': '04:00-04:59', 'days': 29, 'month': 9, 'hour': 4}
# {'': 8453, 'Count_days': 352, 'date': datetime.datetime(2013, 9, 29, 0, 0), 'Hours': '05:00-05:59', 'days': 29, 'month': 9, 'hour': 5}
# {'': 8454, 'Count_days': 352, 'date': datetime.datetime(2013, 9, 29, 0, 0), 'Hours': '06:00-06:59', 'days': 29, 'month': 9, 'hour': 6}
# {'': 8455, 'Count_days': 352, 'date': datetime.datetime(2013, 9, 29, 0, 0), 'Hours': '07:00-07:59', 'days': 29, 'month': 9, 'hour': 7}
# {'': 8456, 'Count_days': 352, 'date': datetime.datetime(2013, 9, 29, 0, 0), 'Hours': '08:00-08:59', 'days': 29, 'month': 9, 'hour': 8}
# {'': 8457, 'Count_days': 352, 'date': datetime.datetime(2013, 9, 29, 0, 0), 'Hours': '09:00-09:59', 'days': 29, 'month': 9, 'hour': 9}
# {'': 8458, 'Count_days': 352, 'date': datetime.datetime(2013, 9, 29, 0, 0), 'Hours': '10:00-10:59', 'days': 29, 'month': 9, 'hour': 10}
# {'': 8459, 'Count_days': 352, 'date': datetime.datetime(2013, 9, 29, 0, 0), 'Hours': '11:00-11:59', 'days': 29, 'month': 9, 'hour': 11}
# {'': 8460, 'Count_days': 352, 'date': datetime.datetime(2013, 9, 29, 0, 0), 'Hours': '12:00-12:59', 'days': 29, 'month': 9, 'hour': 12}
# {'': 8461, 'Count_days': 352, 'date': datetime.datetime(2013, 9, 29, 0, 0), 'Hours': '13:00-13:59', 'days': 29, 'month': 9, 'hour': 13}
# {'': 8462, 'Count_days': 352, 'date': datetime.datetime(2013, 9, 29, 0, 0), 'Hours': '14:00-14:59', 'days': 29, 'month': 9, 'hour': 14}
# {'': 8463, 'Count_days': 352, 'date': datetime.datetime(2013, 9, 29, 0, 0), 'Hours': '15:00-15:59', 'days': 29, 'month': 9, 'hour': 15}
# {'': 8464, 'Count_days': 352, 'date': datetime.datetime(2013, 9, 29, 0, 0), 'Hours': '16:00-16:59', 'days': 29, 'month': 9, 'hour': 16}
# {'': 8465, 'Count_days': 352, 'date': datetime.datetime(2013, 9, 29, 0, 0), 'Hours': '17:00-17:59', 'days': 29, 'month': 9, 'hour': 17}
# {'': 8466, 'Count_days': 352, 'date': datetime.datetime(2013, 9, 29, 0, 0), 'Hours': '18:00-18:59', 'days': 29, 'month': 9, 'hour': 18}
# {'': 8467, 'Count_days': 352, 'date': datetime.datetime(2013, 9, 29, 0, 0), 'Hours': '19:00-19:59', 'days': 29, 'month': 9, 'hour': 19}
# {'': 8468, 'Count_days': 352, 'date': datetime.datetime(2013, 9, 29, 0, 0), 'Hours': '20:00-20:59', 'days': 29, 'month': 9, 'hour': 20}
# {'': 8469, 'Count_days': 352, 'date': datetime.datetime(2013, 9, 29, 0, 0), 'Hours': '21:00-21:59', 'days': 29, 'month': 9, 'hour': 21}
# {'': 8470, 'Count_days': 352, 'date': datetime.datetime(2013, 9, 29, 0, 0), 'Hours': '22:00-22:59', 'days': 29, 'month': 9, 'hour': 22}
# {'': 8471, 'Count_days': 352, 'date': datetime.datetime(2013, 9, 29, 0, 0), 'Hours': '23:00-23:59', 'days': 29, 'month': 9, 'hour': 23}
# {'': 8472, 'Count_days': 353, 'date': datetime.datetime(2013, 9, 30, 0, 0), 'Hours': '00:00-00:59', 'days': 30, 'month': 9, 'hour': 0}
# {'': 8473, 'Count_days': 353, 'date': datetime.datetime(2013, 9, 30, 0, 0), 'Hours': '01:00-01:59', 'days': 30, 'month': 9, 'hour': 1}
# {'': 8474, 'Count_days': 353, 'date': datetime.datetime(2013, 9, 30, 0, 0), 'Hours': '02:00-02:59', 'days': 30, 'month': 9, 'hour': 2}
# {'': 8475, 'Count_days': 353, 'date': datetime.datetime(2013, 9, 30, 0, 0), 'Hours': '03:00-03:59', 'days': 30, 'month': 9, 'hour': 3}
# {'': 8476, 'Count_days': 353, 'date': datetime.datetime(2013, 9, 30, 0, 0), 'Hours': '04:00-04:59', 'days': 30, 'month': 9, 'hour': 4}
# {'': 8477, 'Count_days': 353, 'date': datetime.datetime(2013, 9, 30, 0, 0), 'Hours': '05:00-05:59', 'days': 30, 'month': 9, 'hour': 5}
# {'': 8478, 'Count_days': 353, 'date': datetime.datetime(2013, 9, 30, 0, 0), 'Hours': '06:00-06:59', 'days': 30, 'month': 9, 'hour': 6}
# {'': 8479, 'Count_days': 353, 'date': datetime.datetime(2013, 9, 30, 0, 0), 'Hours': '07:00-07:59', 'days': 30, 'month': 9, 'hour': 7}
# {'': 8480, 'Count_days': 353, 'date': datetime.datetime(2013, 9, 30, 0, 0), 'Hours': '08:00-08:59', 'days': 30, 'month': 9, 'hour': 8}
# {'': 8481, 'Count_days': 353, 'date': datetime.datetime(2013, 9, 30, 0, 0), 'Hours': '09:00-09:59', 'days': 30, 'month': 9, 'hour': 9}
# {'': 8482, 'Count_days': 353, 'date': datetime.datetime(2013, 9, 30, 0, 0), 'Hours': '10:00-10:59', 'days': 30, 'month': 9, 'hour': 10}
# {'': 8483, 'Count_days': 353, 'date': datetime.datetime(2013, 9, 30, 0, 0), 'Hours': '11:00-11:59', 'days': 30, 'month': 9, 'hour': 11}
# {'': 8484, 'Count_days': 353, 'date': datetime.datetime(2013, 9, 30, 0, 0), 'Hours': '12:00-12:59', 'days': 30, 'month': 9, 'hour': 12}
# {'': 8485, 'Count_days': 353, 'date': datetime.datetime(2013, 9, 30, 0, 0), 'Hours': '13:00-13:59', 'days': 30, 'month': 9, 'hour': 13}
# {'': 8486, 'Count_days': 353, 'date': datetime.datetime(2013, 9, 30, 0, 0), 'Hours': '14:00-14:59', 'days': 30, 'month': 9, 'hour': 14}
# {'': 8487, 'Count_days': 353, 'date': datetime.datetime(2013, 9, 30, 0, 0), 'Hours': '15:00-15:59', 'days': 30, 'month': 9, 'hour': 15}
# {'': 8488, 'Count_days': 353, 'date': datetime.datetime(2013, 9, 30, 0, 0), 'Hours': '16:00-16:59', 'days': 30, 'month': 9, 'hour': 16}
# {'': 8489, 'Count_days': 353, 'date': datetime.datetime(2013, 9, 30, 0, 0), 'Hours': '17:00-17:59', 'days': 30, 'month': 9, 'hour': 17}
# {'': 8490, 'Count_days': 353, 'date': datetime.datetime(2013, 9, 30, 0, 0), 'Hours': '18:00-18:59', 'days': 30, 'month': 9, 'hour': 18}
# {'': 8491, 'Count_days': 353, 'date': datetime.datetime(2013, 9, 30, 0, 0), 'Hours': '19:00-19:59', 'days': 30, 'month': 9, 'hour': 19}
# {'': 8492, 'Count_days': 353, 'date': datetime.datetime(2013, 9, 30, 0, 0), 'Hours': '20:00-20:59', 'days': 30, 'month': 9, 'hour': 20}
# {'': 8493, 'Count_days': 353, 'date': datetime.datetime(2013, 9, 30, 0, 0), 'Hours': '21:00-21:59', 'days': 30, 'month': 9, 'hour': 21}
# {'': 8494, 'Count_days': 353, 'date': datetime.datetime(2013, 9, 30, 0, 0), 'Hours': '22:00-22:59', 'days': 30, 'month': 9, 'hour': 22}
# {'': 8495, 'Count_days': 353, 'date': datetime.datetime(2013, 9, 30, 0, 0), 'Hours': '23:00-23:59', 'days': 30, 'month': 9, 'hour': 23}

# %%
evaluate.progressive_val_score(
       dataset= X_y,
       model = model,
       metric = metrics.MAE(),
       moment='date',
       delay=dt.timedelta(days=1),
       print_every=1000
)
# Out:
# MAE: 0.

# %%
from river import metrics
import matplotlib.pyplot as plt

metric = metrics.Rolling(metrics.MAE(), 7)

dates = []
y_trues = []
y_preds = []

X_y = initial_iter()

model = compose.Select( '', 'hour', 'days', 'Count_days')
model |= preprocessing.StandardScaler()
model |= linear_model.LinearRegression(optimizer=optim.SGD(0.001))



# for i in range(0,8496):  #8496
#        x, y = next(X_y)
#        # Obtain the prior prediction and update the model in one go
#        y_pred = model.predict_one(x)
#        model.learn_one(x, y)
#
#        # Update the error metric
#        metric.update(y, y_pred)
#
#        # Store the true value and the prediction
#        dates.append(x['date'])
#        y_trues.append(y)
#        y_preds.append(y_pred)

for i in range(0,8159):  #8496
       x, y = next(X_y)
       # Obtain the prior prediction and update the model in one go

       y_pred = model.predict_one(x)
       model.learn_one(x, y)

       # Update the error metric


       # Store the true value and the prediction
       dates.append(x['date'])
       y_trues.append(y)
       y_preds.append(y_pred)

       if i == 8158:
              for i in range(8159,8495):
                     x, y = next(X_y)
                     y_pred = model.predict_one(x)
                     model.learn_one(x, y_pred)
                     metric.update(y, y_pred)
                     dates.append(x['date'])
                     y_trues.append(y)
                     y_preds.append(y_pred)


# Plot the results
fig, ax = plt.subplots(figsize=(10, 6))
ax.grid(alpha=0.75)
ax.plot(dates, y_trues, lw=3, color='#2ecc71', alpha=0.8, label='Ground truth')
ax.plot(dates, y_preds, lw=3, color='#e74c3c', alpha=0.8, label='Prediction')
ax.legend()
ax.set_title(metric)
# Out:
# Text(0.5, 1.0, 'MAE: 3,249.523984\t(rolling 7)')
# /home/giodefa/anaconda3/envs/Script_Tesi_new/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from river import metrics
import matplotlib.pyplot as plt

metric = metrics.Rolling(metrics.MAE(), 7)

dates = []
y_trues = []
y_preds = []

X_y = initial_iter()

model = compose.Select( '', 'days')
model |= preprocessing.StandardScaler()
model |= linear_model.PARegressor(
       C=0.01,
       mode=2,
       eps=0.1,
       learn_intercept=False
)



# for i in range(0,8496):  #8496
#        x, y = next(X_y)
#        # Obtain the prior prediction and update the model in one go
#        y_pred = model.predict_one(x)
#        model.learn_one(x, y)
#
#        # Update the error metric
#        metric.update(y, y_pred)
#
#        # Store the true value and the prediction
#        dates.append(x['date'])
#        y_trues.append(y)
#        y_preds.append(y_pred)

for i in range(0,8159):  #8496
       x, y = next(X_y)
       # Obtain the prior prediction and update the model in one go

       y_pred = model.predict_one(x)
       model.learn_one(x, y)

       # Update the error metric


       # Store the true value and the prediction
       dates.append(x['date'])
       y_trues.append(y)
       y_preds.append(y_pred)

       if i == 8158:
              for i in range(8159,8495):
                     x, y = next(X_y)
                     y_pred = model.predict_one(x)
                     model.learn_one(x, y_pred)
                     metric.update(y, y_pred)
                     dates.append(x['date'])
                     y_trues.append(y)
                     y_preds.append(y_pred)


# Plot the results
fig, ax = plt.subplots(figsize=(10, 6))
ax.grid(alpha=0.75)
ax.plot(dates, y_trues, lw=3, color='#2ecc71', alpha=0.8, label='Ground truth')
ax.plot(dates, y_preds, lw=3, color='#e74c3c', alpha=0.8, label='Prediction')
ax.legend()
ax.set_title(metric)
# Out:
# Text(0.5, 1.0, 'MAE: 3,938.352024\t(rolling 7)')
# /home/giodefa/anaconda3/envs/Script_Tesi_new/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from river import metrics
import matplotlib.pyplot as plt


metric = metrics.Rolling(metrics.MAE(), 7)

dates = []
y_trues = []
y_preds = []
err_down = []
err_up = []

X_y = initial_iter()

model = compose.Select('',  'days', 'Count_days')
model |= preprocessing.StandardScaler()

model |= ensemble.AdaptiveRandomForestRegressor()
for i in range(0,8496):  #8496
       x, y = next(X_y)
       # Obtain the prior prediction and update the model in one go
       y_pred = model.predict_one(x)
       model.learn_one(x, y)

       # Update the error metric
       metric.update(y, y_pred)

       # Store the true value and the prediction
       dates.append(x['date'])
       y_trues.append(y)
       y_preds.append(y_pred)


# for i in range(0,8159):  #8496
#        x, y = next(X_y)
#        # Obtain the prior prediction and update the model in one go
#
#        y_pred = model.predict_one(x)
#        model.learn_one(x, y)
#
#        # Update the error metric
#
#
#        # Store the true value and the prediction
#        dates.append(x['date'])
#        y_trues.append(y)
#        y_preds.append(y_pred)
#        err_down.append(np.percentile(model.predict_one(x), (100 - 95) / 2. ))
#        err_up.append(np.percentile(model.predict_one(x), 100 - (100 - 95) / 2.))
#        if i == 8158:
#               for i in range(8159,8495):
#                      x, y = next(X_y)
#                      y_pred = model.predict_one(x)
#                      model.learn_one(x, y_pred)
#                      metric.update(y, y_pred)
#                      dates.append(x['date'])
#                      y_trues.append(y)
#                      y_preds.append(y_pred)
#                      err_down.append(np.percentile(model.predict_one(x), (100 - 95) / 2. ))
#                      err_up.append(np.percentile(model.predict_one(x), 100 - (100 - 95) / 2.))





# Plot the results
fig, ax = plt.subplots(figsize=(10, 6))
ax.grid(alpha=0.75)
ax.plot(dates, y_trues, lw=3, color='#2ecc71', alpha=0.8, label='Ground truth')
ax.plot(dates, y_preds, lw=3, color='#e74c3c', alpha=0.8, label='Prediction')
#ax.fill_between(dates, err_down, err_up, color='#e74c3c', alpha=0.3, label='Prediction interval')
ax.legend()
ax.set_title(metric)
# Out:
# Text(0.5, 1.0, 'MAE: 2,890.270686\t(rolling 7)')
# /home/giodefa/anaconda3/envs/Script_Tesi_new/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
X_y = initial_iter()

model = compose.Select( '', 'hour', 'days', 'Count_days')
model |= preprocessing.StandardScaler()
model |= ensemble.AdaptiveRandomForestRegressor()

evaluate.progressive_val_score(
    dataset=X_y,
    model=model,
    metric= metrics.MAE(),
    moment='date',
    delay=dt.timedelta(minutes=60),
    print_every=1000
)
# Out:
# [1,000] MAE: 4,992.984298
# [2,000] MAE: 3,860.456174
# [3,000] MAE: 3,400.074817
# [4,000] MAE: 3,034.31124
# [5,000] MAE: 2,795.357412
# [6,000] MAE: 2,640.207152
# [7,000] MAE: 2,527.363591
# [8,000] MAE: 2,448.242731
# MAE: 2,386.669076

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.grid(alpha=0.75)
#ax.plot(dates[3000:8495], y_trues[3000:8495], lw=3, color='#2ecc71', alpha=0.8, label='Ground truth')
ax.plot(dates[3000:8495], y_preds[3000:8495], lw=3, color='#e74c3c', alpha=0.8, label='Prediction')
ax.fill_between(dates[3000:8495], err_down[3000:8495], err_up[3000:8495], color='#e74c3c', alpha=0.1, label='Prediction interval')
ax.legend()
ax.set_title(metric)
# Out:
# Text(0.5, 1.0, 'MAE: 2,906.590158\t(rolling 7)')
# C:\Users\giode\PycharmProjects\Script_Tesi_new\venv\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
X_y = initial_iter()
model = compose.Select( '', 'hour', 'days', 'Count_days')

model |= preprocessing.StandardScaler()
model |= ensemble.AdaptiveRandomForestRegressor()

evaluate.progressive_val_score(
       dataset= X_y,
       model = model,
       metric = metrics.MAE(),
       moment='date',
       delay=dt.timedelta(days=7),
       print_every=1000
)
# Out:
# [1,000] MAE: 30,117.880018
# [2,000] MAE: 17,755.923125
# [3,000] MAE: 13,005.290552
# [4,000] MAE: 10,299.425698
# [5,000] MAE: 8,723.123964
# [6,000] MAE: 7,612.78988
# [7,000] MAE: 6,898.000676
# [8,000] MAE: 6,595.118928
# MAE: 6,395.702299

# %%
dati
# Out:
#       Count_days       date        Hours  Water_volume  days  month  hour
# 0              0 2012-10-02  00:00-00:59       13815.2     2     10     0
# 1              0 2012-10-02  01:00-01:59       13290.0     2     10     1
# 2              0 2012-10-02  02:00-02:59       13416.2     2     10     2
# 3              0 2012-10-02  03:00-03:59       13424.6     2     10     3
# 4              0 2012-10-02  04:00-04:59       14607.3     2     10     4
# ...          ...        ...          ...           ...   ...    ...   ...
# 8491         353 2013-09-30  19:00-19:59       31425.0    30      9    19
# 8492         353 2013-09-30  20:00-20:59       27188.7    30      9    20
# 8493         353 2013-09-30  21:00-21:59       22630.9    30      9    21
# 8494         353 2013-09-30  22:00-22:59       19858.5    30      9    22
# 8495         353 2013-09-30  23:00-23:59       14057.3    30      9    23
#
# [8496 rows x 7 columns]

# %%
from river import metrics
import matplotlib.pyplot as plt


metric = metrics.Rolling(metrics.MAE(), 7)

dates = []
y_trues = []
y_preds = []
err_down = []
err_up = []

X_y = initial_iter()

model = compose.Select( '', 'hour', 'days', 'Count_days')
model |= preprocessing.StandardScaler()

model |= ensemble.BaggingRegressor(
       model=linear_model.LinearRegression(),
       n_models=3
)
# for i in range(0,8496):  #8496
#        x, y = next(X_y)
#        # Obtain the prior prediction and update the model in one go
#
#        y_pred = model.predict_one(x)
#        model.learn_one(x, y)
#
#        # Update the error metric
#        metric.update(y, y_pred)
#
#        # Store the true value and the prediction
#        dates.append(x['date'])
#        y_trues.append(y)
#        y_preds.append(y_pred)

for i in range(0,8159):  #8496
       x, y = next(X_y)
       # Obtain the prior prediction and update the model in one go

       y_pred = model.predict_one(x)
       model.learn_one(x, y)

       # Update the error metric


       # Store the true value and the prediction
       dates.append(x['date'])
       y_trues.append(y)
       y_preds.append(y_pred)
       err_down.append(np.percentile(y_pred, (100 - 95) / 2. ))
       err_up.append(np.percentile(y_pred, 100 - (100 - 95) / 2.))
       if i == 8158:
              for i in range(8159,8495):
                     x, y = next(X_y)
                     y_pred = model.predict_one(x)
                     metric.update(y, y_pred)
                     dates.append(x['date'])
                     y_trues.append(y)
                     y_preds.append(y_pred)
                     err_down.append(np.percentile(y_pred, (100 - 95) / 2. ))
                     err_up.append(np.percentile(y_pred, 100 - (100 - 95) / 2.))



# Plot the results
fig, ax = plt.subplots(figsize=(10, 6))
ax.grid(alpha=0.75)
ax.plot(dates, y_trues, lw=3, color='#2ecc71', alpha=0.8, label='Ground truth')
ax.plot(dates, y_preds, lw=3, color='#e74c3c', alpha=0.8, label='Prediction')
ax.legend()
ax.set_title(metric)
# Out:
# Text(0.5, 1.0, 'MAE: 3,228.274886\t(rolling 7)')
# /home/giodefa/anaconda3/envs/Script_Tesi_new/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
X_y = initial_iter()
model = compose.Select( '', 'hour', 'days', 'Count_days')

model |= preprocessing.StandardScaler()
model |= ensemble.BaggingRegressor(
       model=linear_model.LinearRegression(),
       n_models=3
)

evaluate.progressive_val_score(
       dataset= X_y,
       model = model,
       metric = metrics.MAE(),
       moment='date',
       delay=dt.timedelta(days=7),
       print_every=1000
)
# Out:
# [1,000] MAE: 25,095.433992
# [2,000] MAE: 16,192.128835
# [3,000] MAE: 13,211.980582
# [4,000] MAE: 11,737.909569
# [5,000] MAE: 10,769.577798
# [6,000] MAE: 10,169.063827
# [7,000] MAE: 9,628.527462
# [8,000] MAE: 9,068.73117
# MAE: 8,913.775691

# %%
from river import metrics
import matplotlib.pyplot as plt


metric = metrics.Rolling(metrics.MAE(), 7)

dates = []
y_trues = []
y_preds = []

X_y = initial_iter()

base_model = tree.HoeffdingTreeRegressor(grace_period=50)
model = compose.Select()
model |= ensemble.SRPRegressor(
       model=base_model,
       training_method='patches',
       n_models=10
)
for i in range(0,8496):  #8496
       x, y = next(X_y)
       # Obtain the prior prediction and update the model in one go

       y_pred = model.predict_one(x)
       model.learn_one(x, y)

       # Update the error metric
       metric.update(y, y_pred)


       # Store the true value and the prediction
       dates.append(x['date'])
       y_trues.append(y)
       y_preds.append(y_pred)


# Plot the results
fig, ax = plt.subplots(figsize=(10, 6))
ax.grid(alpha=0.75)
ax.plot(dates, y_trues, lw=3, color='#2ecc71', alpha=0.8, label='Ground truth')
ax.plot(dates, y_preds, lw=3, color='#e74c3c', alpha=0.8, label='Prediction')
ax.legend()
ax.set_title(metric)
# Out:
# Text(0.5, 1.0, 'MAE: 4,645.489221\t(rolling 7)')
# /home/giodefa/anaconda3/envs/Script_Tesi_new/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
ax.set_title(metric)
X_y = initial_iter()
model = compose.Select()
model |= ensemble.SRPRegressor(
       model=base_model,
       training_method='patches',
       n_models=10
)

evaluate.progressive_val_score(
       dataset=X_y,
       model=model,
       metric=metrics.Rolling(metrics.MAE(), 168),
       moment='date',
       delay=dt.timedelta(hours=12),
       print_every=1000
)
# Out:
# [1,000] MAE: 6,712.867221	(rolling 168)
# [2,000] MAE: 5,896.340512	(rolling 168)
# [3,000] MAE: 6,772.985823	(rolling 168)
# [4,000] MAE: 6,689.094126	(rolling 168)
# [5,000] MAE: 6,756.041672	(rolling 168)
# [6,000] MAE: 7,067.565993	(rolling 168)
# [7,000] MAE: 5,676.058553	(rolling 168)
# [8,000] MAE: 6,382.090415	(rolling 168)
# MAE: 6,395.170317	(rolling 168)

# %%
ax.set_title(metric)
X_y = initial_iter()
model = compose.Select()
model |= ensemble.SRPRegressor(
       model=base_model,
       training_method='patches',
       n_models=10
)

evaluate.progressive_val_score(
       dataset=X_y,
       model=model,
       metric=metrics.MAE(),
       moment='date',
       delay=dt.timedelta(hours=1),
       print_every=1000
)
# Out:
# [1,000] MAE: 7,230.537869
# [2,000] MAE: 6,928.317206
# [3,000] MAE: 6,833.458095
# [4,000] MAE: 6,835.78609
# [5,000] MAE: 6,808.081239
# [6,000] MAE: 6,795.950119
# [7,000] MAE: 6,695.142125
# [8,000] MAE: 6,433.391682
# MAE: 6,418.060992

# %%
def initial_iter():

       path = '/home/giodefa/PycharmProjects/Script_Tesi_new/Script/DatiTesi/dativolum.csv'

       X_y = stream.iter_csv(
              filepath_or_buffer=path,
              converters={
                     'Count_days': int,
                     'Water_volume': float,
                     'days': int,
                     'month': int,
                     'hour': int,
                     '': int
                     },
              parse_dates={'date': '%Y-%m-%d'},
              target='Water_volume'
                      )
       return X_y

# %%
from river import metrics
import matplotlib.pyplot as plt


metric = metrics.Rolling(metrics.MAE(), 7)

dates = []
y_trues = []
y_preds = []

X_y = initial_iter()
model = compose.Select( )
model |= neighbors.KNNRegressor(
       window_size= 50,
       n_neighbors=5
)
for i in range(0,8496):  #8496
       x, y = next(X_y)
       # Obtain the prior prediction and update the model in one go

       y_pred = model.predict_one(x)
       model.learn_one(x, y)

       # Update the error metric
       # Update the error metric
       metric.update(y, y_pred)

       # Store the true value and the prediction
       dates.append(x['date'])
       y_trues.append(y)
       y_preds.append(y_pred)


# Plot the results
fig, ax = plt.subplots(figsize=(10, 6))
ax.grid(alpha=0.75)
ax.plot(dates, y_trues, lw=3, color='#2ecc71', alpha=0.8, label='Ground truth')
ax.plot(dates, y_preds, lw=3, color='#e74c3c', alpha=0.8, label='Prediction')
ax.legend()
ax.set_title(metric)
# Out:
# Text(0.5, 1.0, 'MAE: 4,202.057143\t(rolling 7)')
# /home/giodefa/anaconda3/envs/Script_Tesi_new/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
X_y = initial_iter()
model = compose.Select()
model |= neighbors.KNNRegressor(
       window_size= 50,
       n_neighbors=5
)

evaluate.progressive_val_score(
       dataset= X_y,
       model = model,
       metric = metrics.Rolling(metrics.MAE(), 168),
       moment='date',
       delay=dt.timedelta(hours=12),
       print_every=1000
)
# Out:
# [1,000] MAE: 8,192.216667	(rolling 168)
# [2,000] MAE: 6,280.319048	(rolling 168)
# [3,000] MAE: 8,123.120238	(rolling 168)
# [4,000] MAE: 8,166.877381	(rolling 168)
# [5,000] MAE: 8,017.950595	(rolling 168)
# [6,000] MAE: 8,744.714881	(rolling 168)
# [7,000] MAE: 6,552.132143	(rolling 168)
# [8,000] MAE: 7,416.205952	(rolling 168)
# MAE: 7,938.62381	(rolling 168)

# %%
ax.set_title(metric)
X_y = initial_iter()
model = compose.Select()
model |= neighbors.KNNRegressor(
       window_size=50,
       n_neighbors=5
)

evaluate.progressive_val_score(
       dataset=X_y,
       model=model,
       metric=metrics.MAE(),
       moment='date',
       delay=dt.timedelta(hours=12),
       print_every=1000
)
# Out:
# [1,000] MAE: 8,852.6556
# [2,000] MAE: 8,282.93836
# [3,000] MAE: 8,146.29658
# [4,000] MAE: 8,216.550618
# [5,000] MAE: 8,163.177626
# [6,000] MAE: 8,156.093228
# [7,000] MAE: 8,002.061496
# [8,000] MAE: 7,637.195396
# MAE: 7,632.871277

# %%
X_y = initial_iter()
next(X_y)
# Out:
# ({'': 0,
#   'Count_days': 0,
#   'date': datetime.datetime(2012, 10, 2, 0, 0),
#   'Hours': '00:00-00:59',
#   'days': 2,
#   'month': 10,
#   'hour': 0},
#  13815.2)

# %%
from river import metrics
import matplotlib.pyplot as plt


metric = metrics.Rolling(metrics.MAE(), 7)

dates = []
y_trues = []
y_preds = []

X_y = initial_iter()
model = compose.Select()
model |= (
       preprocessing.StandardScaler() |
       neural_net.MLPRegressor(
              hidden_dims=(15,30),
              activations=(
                     neural_net.activations.ReLU,
                     neural_net.activations.ReLU,
                     neural_net.activations.Identity
              ),
              optimizer=optim.SGD()
       )
)
for i in range(0,8496):  #8496
       x, y = next(X_y)
       # Obtain the prior prediction and update the model in one go
       y_pred = model.predict_one(x)
       model.learn_one(x, y)

       # Update the error metric
       metric.update(y, y_pred)

       # Store the true value and the prediction
       dates.append(x['date'])
       y_trues.append(y)
       y_preds.append(y_pred)


# for i in range(0,8159):  #8496
#        x, y = next(X_y)
#        # Obtain the prior prediction and update the model in one go
#
#        y_pred = model.predict_one(x)
#        model.learn_one(x, y)
#
#        # Update the error metric
#
#
#        # Store the true value and the prediction
#        dates.append(x['date'])
#        y_trues.append(y)
#        y_preds.append(y_pred)
#
#        if i == 8158:
#               for i in range(8159,8495):
#                      x, y = next(X_y)
#                      y_pred = model.predict_one(x)
#                      model.learn_one(x, y_pred)
#                      metric.update(y, y_pred)
#                      dates.append(x['date'])
#                      y_trues.append(y)
#                      y_preds.append(y_pred)


# Plot the results
fig, ax = plt.subplots(figsize=(10, 6))
ax.grid(alpha=0.75)
ax.plot(dates, y_trues, lw=3, color='#2ecc71', alpha=0.8, label='Ground truth')
ax.plot(dates, y_preds, lw=3, color='#e74c3c', alpha=0.8, label='Prediction')
ax.legend()
ax.set_title(metric)
# Out:
# Text(0.5, 1.0, 'MAE: 3,251.827275\t(rolling 7)')
# /home/giodefa/anaconda3/envs/Script_Tesi_new/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
X_y = initial_iter()
model = compose.Select()
model |= (
       preprocessing.StandardScaler() |
       neural_net.MLPRegressor(
              hidden_dims=(15,30),
              activations=(
                     neural_net.activations.ReLU,
                     neural_net.activations.ReLU,
                     neural_net.activations.Identity
              ),
              optimizer=optim.SGD()
       )
)

evaluate.progressive_val_score(
       dataset= X_y,
       model = model,
       metric = metrics.Rolling(metrics.MAE(), 168),
       moment='date',
       delay=dt.timedelta(hours=12),
       print_every=1000
)
# Out:
# [1,000] MAE: 6,749.073769	(rolling 168)
# [2,000] MAE: 5,771.147549	(rolling 168)
# [3,000] MAE: 6,800.693615	(rolling 168)
# [4,000] MAE: 6,698.227391	(rolling 168)
# [5,000] MAE: 6,641.079794	(rolling 168)
# [6,000] MAE: 7,075.595865	(rolling 168)
# [7,000] MAE: 5,646.879548	(rolling 168)
# [8,000] MAE: 6,303.947233	(rolling 168)
# MAE: 6,404.058457	(rolling 168)

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.grid(alpha=0.75)
ax.plot(dates[8000:8495], y_trues[8000:8495], lw=3, color='#2ecc71', alpha=0.8, label='Ground truth')
ax.plot(dates[8000:8495], y_preds[8000:8495], lw=3, color='#e74c3c', alpha=0.8, label='Prediction')
ax.legend()
ax.set_title(metric)
# Out:
# Text(0.5, 1.0, 'MAE: 3,251.827275\t(rolling 7)')
# /home/giodefa/anaconda3/envs/Script_Tesi_new/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
X_y = initial_iter()
model = compose.Select( '', 'hour', 'days', 'Count_days')

model = compose.Select( '', 'hour', 'days', 'Count_days')
model |= (
       preprocessing.StandardScaler() |
       neural_net.MLPRegressor(
              hidden_dims=(5,5),
              activations=(
                     neural_net.activations.ReLU,
                     neural_net.activations.ReLU,
                     neural_net.activations.Identity
              ),
              optimizer=optim.SGD()
       )
)

evaluate.progressive_val_score(
       dataset= X_y,
       model = model,
       metric = metrics.MAE(),
       moment='date',
       delay=dt.timedelta(hours=1),
       print_every=1000
)
# Out:
# [1,000] MAE: 69,249,599.926571
# [2,000] MAE: 34,628,100.328708
# [3,000] MAE: 23,087,606.986736
# [4,000] MAE: 17,317,418.591073
# [5,000] MAE: 13,855,262.67481
# [6,000] MAE: 11,547,163.713815
# [7,000] MAE: 9,898,432.813785
# [8,000] MAE: 8,661,675.871232
# MAE: 8,156,363.235877

# %%
splitter = [i*2 for i in range(0,300)]
len(splitter)
# Out:
# 300

# %%
from river import metrics
import matplotlib.pyplot as plt


metric = metrics.Rolling(metrics.MAE(), 7)

dates = []
y_trues = []
y_preds = []

result = []


X_y = initial_iter()
model = compose.Select()
model |= tree.HoeffdingAdaptiveTreeRegressor(
       grace_period=20,
       leaf_prediction='adaptive',
       min_samples_split=30
       )

# for i in range(0,8496):  #8496
#        x, y = next(X_y)
#        # Obtain the prior prediction and update the model in one go
#        y_pred = model.predict_one(x)
#        model.learn_one(x, y)
#
#        # Update the error metric
#        metric.update(y, y_pred)
#
#        # Store the true value and the prediction
#        dates.append(x['date'])
#        y_trues.append(y)
#        y_preds.append(y_pred)
#        result.append(metric)

for i in range(0,8159):  #8496
       x, y = next(X_y)
       # Obtain the prior prediction and update the model in one go

       y_pred = model.predict_one(x)
       model.learn_one(x, y)

       # Update the error metric


       # Store the true value and the prediction
       dates.append(x['date'])
       y_trues.append(y)
       y_preds.append(y_pred)

       if i == 8158:
              for i in range(8159,8495):
                     x, y = next(X_y)
                     y_pred = model.predict_one(x)
                     model.learn_one(x, y_pred)
                     metric.update(y, y_pred)
                     dates.append(x['date'])
                     y_trues.append(y)
                     y_preds.append(y_pred)

# Plot the results
fig, ax = plt.subplots(figsize=(10, 6))
ax.grid(alpha=0.75)
ax.plot(dates, y_trues, lw=3, color='#2ecc71', alpha=0.8, label='Ground truth')
ax.plot(dates, y_preds, lw=3, color='#e74c3c', alpha=0.8, label='Prediction')
ax.legend()
ax.set_title(metric)
# Out:
# Text(0.5, 1.0, 'MAE: 3,403.905443\t(rolling 7)')
# /home/giodefa/anaconda3/envs/Script_Tesi_new/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
X_y = initial_iter()
model = compose.Select()
model |= tree.HoeffdingAdaptiveTreeRegressor(
       grace_period=20,
       leaf_prediction='adaptive',
       min_samples_split=30
       )

evaluate.progressive_val_score(
       dataset= X_y,
       model = model,
       metric = metrics.Rolling(metrics.MAE(), 168),
       moment='date',
       delay=dt.timedelta(hours=12),
       print_every=1000
)
# Out:
# [1,000] MAE: 6,697.901041	(rolling 168)
# [2,000] MAE: 5,792.09442	(rolling 168)
# [3,000] MAE: 6,883.272827	(rolling 168)
# [4,000] MAE: 6,741.825042	(rolling 168)
# [5,000] MAE: 6,513.782813	(rolling 168)
# [6,000] MAE: 6,989.927351	(rolling 168)
# [7,000] MAE: 5,696.962418	(rolling 168)
# [8,000] MAE: 6,286.091969	(rolling 168)
# MAE: 6,507.729921	(rolling 168)

# %%
from river import metrics
import matplotlib.pyplot as plt


metric = metrics.Rolling(metrics.MAE(), 7)

dates = []
y_trues = []
y_preds = []

X_y = initial_iter()
model = compose.Select()
model |= tree.HoeffdingTreeRegressor(
       leaf_prediction='adaptive'
)

for i in range(0,8496):  #8496
       x, y = next(X_y)
       # Obtain the prior prediction and update the model in one go
       y_pred = model.predict_one(x)
       model.learn_one(x, y)

       # Update the error metric
       metric.update(y, y_pred)

       # Store the true value and the prediction
       dates.append(x['date'])
       y_trues.append(y)
       y_preds.append(y_pred)

# for i in range(0,8159):  #8496
#        x, y = next(X_y)
#        # Obtain the prior prediction and update the model in one go
#
#        y_pred = model.predict_one(x)
#        model.learn_one(x, y)
#
#        # Update the error metric
#
#
#        # Store the true value and the prediction
#        dates.append(x['date'])
#        y_trues.append(y)
#        y_preds.append(y_pred)
#
#        if i == 8158:
#               for i in range(8159,8495):
#                      x, y = next(X_y)
#                      y_pred = model.predict_one(x)
#                      model.learn_one(x, y_pred)
#                      metric.update(y, y_pred)
#                      dates.append(x['date'])
#                      y_trues.append(y)
#                      y_preds.append(y_pred)

# Plot the results
fig, ax = plt.subplots(figsize=(10, 6))
ax.grid(alpha=0.75)
ax.plot(dates, y_trues, lw=3, color='#2ecc71', alpha=0.8, label='Ground truth')
ax.plot(dates, y_preds, lw=3, color='#e74c3c', alpha=0.8, label='Prediction')
ax.legend()
ax.set_title(metric)
# Out:
# Text(0.5, 1.0, 'MAE: 4,988.572758\t(rolling 7)')
# /home/giodefa/anaconda3/envs/Script_Tesi_new/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
X_y = initial_iter()
model = compose.Select()
model |= tree.HoeffdingTreeRegressor(
       leaf_prediction='adaptive'
)

evaluate.progressive_val_score(
       dataset= X_y,
       model = model,
       metric = metrics.Rolling(metrics.MAE(), 7),
       moment='date',
       delay=dt.timedelta(hours=12),
       print_every=1000
)
# Out:
# [1,000] MAE: 4,977.807433	(rolling 7)
# [2,000] MAE: 8,057.096643	(rolling 7)
# [3,000] MAE: 4,057.944453	(rolling 7)
# [4,000] MAE: 6,372.722382	(rolling 7)
# [5,000] MAE: 10,744.787291	(rolling 7)
# [6,000] MAE: 6,275.070186	(rolling 7)
# [7,000] MAE: 3,524.385993	(rolling 7)
# [8,000] MAE: 9,559.793121	(rolling 7)
# MAE: 4,876.541231	(rolling 7)
